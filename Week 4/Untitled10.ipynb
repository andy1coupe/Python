# %%
import pymysql 
import sqlalchemy 
from sqlalchemy import inspect 
from sqlalchemy import create_engine 
import pandas as pd

# %%
import getpass # optional - to anonymise the password

# %%
password=getpass.getpass() # optional - password
# Out:
# ········

# %%
connection_string='mysql+pymysql://root:'+password+'@Macbooks-MacBook-Pro.local/bank'
# 'dialect+driver://username:password@port/schema'
engine=create_engine(connection_string)

# %%
df=pd.read_sql_query('select * from loan',engine) 
#this is how we test to see if it works
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/AndyClass/lib/python3.8/site-packages/pymysql/connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~/opt/anaconda3/envs/AndyClass/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     786     err = None
# --> 787     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     788         af, socktype, proto, canonname, sa = res
#
# ~/opt/anaconda3/envs/AndyClass/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...
