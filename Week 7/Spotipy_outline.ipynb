# %% [markdown]
# ## Spotipy API
#
# Create an Spotify account and follow these steps to register an app: https://developer.spotify.com/documentation/general/guides/app-settings/
#
# After the app is created, you can see it on your dashboard
# https://developer.spotify.com/dashboard/applications
#
# Click on it and you'll find the client id and client secret.

# %% [markdown]
# #### Authentification

# %%
import spotipy # install if needed
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import getpass

# %%
client_id=str(getpass.getpass('enter your client id?'))
client_secret=str(getpass.getpass('enter your clientsecret?'))
# Out:
# enter your client id?········
# enter your clientsecret?········

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret))

# %% [markdown]
# # Basic Query
# #### Searching songs with 'queries' with `sp.search`

# %%
results = sp.search(q='Queen',limit=50)

# %% [markdown]
# - explore the object returned by the request:

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Queen&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#        'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#        'id': '2cFrymmkijnjDg9SS92EPM',
#        'name': 'blackbear',
#        'type': 'artist',
#        'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4UxlLk460BnmQlRV3WiORh'},
#      'href': 'https://api.spotify.com/v1/albums/4UxlLk460BnmQlRV3WiORh',
#      'id': '4UxlLk460BnmQlRV3WiORh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e9b6f26ff354f4d70847f02d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e9b6f26ff354f4d70847f02d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e9b6f26ff354f4d70847f02d',
#        'width': 64}],
#      'name': 'everything means nothing',
#      'release_date': '2020-08-21',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4UxlLk460BnmQlRV3WiORh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#       'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#       'id': '2cFrymmkijnjDg9SS92EPM',
#       'name': 'blackbear',
#       'type': 'artist',
#       'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 171171,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG12000337'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1xyUCr7dIJYaUaaiDf4Q1L'},
#     'href': 'https://api.spotify.com/v1/tracks/1xyUCr7dIJYaUaaiDf4Q1L',
#     'id': '1xyUCr7dIJYaUaaiDf4Q1L',
#     'is_local': False,
#     'name': 'queen of broken hearts',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8a06c5cf6d0b336f8a467aedb7a09a3277129a9e?cid=85b083e9a83647369e363f8e7cf8158e',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1xyUCr7dIJYaUaaiDf4Q1L'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LcJLqbBmaGUft1e9Mm8HV'},
#        'href': 'https://api.spotify.com/v1/artists/0LcJLqbBmaGUft1e9Mm8HV',
#        'id': '0LcJLqbBmaGUft1e9Mm8HV',
#        'name': 'ABBA',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LcJLqbBmaGUft1e9Mm8HV'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1V6a99EbTTIegOhWoPxYI9'},
#      'href': 'https://api.spotify.com/v1/albums/1V6a99EbTTIegOhWoPxYI9',
#      'id': '1V6a99EbTTIegOhWoPxYI9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27370f7a1b35d5165c85b95a0e0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0270f7a1b35d5165c85b95a0e0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485170f7a1b35d5165c85b95a0e0',
#        'width': 64}],
#      'name': 'Arrival',
#      'release_date': '1976',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1V6a99EbTTIegOhWoPxYI9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LcJLqbBmaGUft1e9Mm8HV'},
#       'href': 'https://api.spotify.com/v1/artists/0LcJLqbBmaGUft1e9Mm8HV',
#       'id': '0LcJLqbBmaGUft1e9Mm8HV',
#       'name': 'ABBA',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LcJLqbBmaGUft1e9Mm8HV'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 230400,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEAYD7601020'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GjEhVFGZW8afUYGChu3Rr'},
#     'href': 'https://api.spotify.com/v1/tracks/0GjEhVFGZW8afUYGChu3Rr',
#     'id': '0GjEhVFGZW8afUYGChu3Rr',
#     'is_local': False,
#     'name': 'Dancing Queen',
#     'popularity': 80,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0GjEhVFGZW8afUYGChu3Rr'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#        'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#        'id': '1dfeR4HaWDbWqFHLkxsg1d',
#        'name': 'Queen',
#        'type': 'artist',
#        'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7C2DKB8C12LqxMkfJRwTo9'},
#      'href': 'https://api.spotify.com/v1/albums/7C2DKB8C12LqxMkfJRwTo9',
#      'id': '7C2DKB8C12LqxMkfJRwTo9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735a7602f0e508660b2ba40f8c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025a7602f0e508660b2ba40f8c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515a7602f0e508660b2ba40f8c',
#        'width': 64}],
#      'name': 'Stone Cold Classics',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:7C2DKB8C12LqxMkfJRwTo9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#       'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#       'id': '1dfeR4HaWDbWqFHLkxsg1d',
#       'name': 'Queen',
#       'type': 'artist',
#       'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 355400,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEE0500364'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6l8GvAyoUZwWDgF1e4822w'},
#     'href': 'https://api.spotify.com/v1/tracks/6l8GvAyoUZwWDgF1e4822w',
#     'id': '6l8GvAyoUZwWDgF1e4822w',
#     'is_local': False,
#     'name': 'Bohemian Rhapsody',
#     'popularity': 65,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6l8GvAyoUZwWDgF1e4822w'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tkZthBATD0S45hm1DmB2O'},
#        'href': 'https://api.spotify.com/v1/artists/3tkZthBATD0S45hm1DmB2O',
#        'id': '3tkZthBATD0S45hm1DmB2O',
#        'name': 'Sammy Kershaw',
#        'type': 'artist',
#        'uri': 'spotify:artist:3tkZthBATD0S45hm1DmB2O'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/30ORdfQ1Movxqmpf3qkrMQ'},
#      'href': 'https://api.spotify.com/v1/albums/30ORdfQ1Movxqmpf3qkrMQ',
#      'id': '30ORdfQ1Movxqmpf3qkrMQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735b82a639a05848f834f33c59',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025b82a639a05848f834f33c59',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515b82a639a05848f834f33c59',
#        'width': 64}],
#      'name': 'Haunted Heart',
#      'release_date': '1993-03-09',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:30ORdfQ1Movxqmpf3qkrMQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tkZthBATD0S45hm1DmB2O'},
#       'href': 'https://api.spotify.com/v1/artists/3tkZthBATD0S45hm1DmB2O',
#       'id': '3tkZthBATD0S45hm1DmB2O',
#       'name': 'Sammy Kershaw',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tkZthBATD0S45hm1DmB2O'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 211200,
#     'explicit': False,
#     'external_ids': {'isrc': 'USPR39302707'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Wz9Fm9ZyhpaRGxMlSR5G4'},
#     'href': 'https://api.spotify.com/v1/tracks/3Wz9Fm9ZyhpaRGxMlSR5G4',
#     'id': '3Wz9Fm9ZyhpaRGxMlSR5G4',
#     'is_local': False,
#     'name': 'Queen Of My Double Wide Trailer',
#     'popularity': 59,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3Wz9Fm9ZyhpaRGxMlSR5G4'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6PXS4YHDkKvl1wkIl4V8DL'},
#        'href': 'https://api.spotify.com/v1/artists/6PXS4YHDkKvl1wkIl4V8DL',
#        'id': '6PXS4YHDkKvl1wkIl4V8DL',
#        'name': 'Fetty Wap',
#        'type': 'artist',
#        'uri': 'spotify:artist:6PXS4YHDkKvl1wkIl4V8DL'}],
#      'available_markets': ['AE',
#       'AG',
#       'AL',
#       'AO',
#       'AR',
#       'BA',
#       'BB',
#       'BD',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CZ',
#       'DJ',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'FJ',
#       'FM',
#       'GA',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IQ',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LV',
#       'LY',
#       'MA',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2gKQvajkEEaDtkqJ8FJ4uw'},
#      'href': 'https://api.spotify.com/v1/albums/2gKQvajkEEaDtkqJ8FJ4uw',
#      'id': '2gKQvajkEEaDtkqJ8FJ4uw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de6bd09b07e2b4af4e409f6c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de6bd09b07e2b4af4e409f6c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de6bd09b07e2b4af4e409f6c',
#        'width': 64}],
#      'name': 'Fetty Wap (Deluxe)',
#      'release_date': '2015-09-25',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:2gKQvajkEEaDtkqJ8FJ4uw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6PXS4YHDkKvl1wkIl4V8DL'},
#       'href': 'https://api.spotify.com/v1/artists/6PXS4YHDkKvl1wkIl4V8DL',
#       'id': '6PXS4YHDkKvl1wkIl4V8DL',
#       'name': 'Fetty Wap',
#       'type': 'artist',
#       'uri': 'spotify:artist:6PXS4YHDkKvl1wkIl4V8DL'}],
#     'available_markets': ['AE',
#      'AG',
#      'AL',
#      'AO',
#      'AR',
#      'BA',
#      'BB',
#      'BD',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CZ',
#      'DJ',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'FJ',
#      'FM',
#      'GA',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IQ',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LV',
#      'LY',
#      'MA',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 222093,
#     'explicit': True,
#     'external_ids': {'isrc': 'QM7XC1400004'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2d8JP84HNLKhmd6IYOoupQ'},
#     'href': 'https://api.spotify.com/v1/tracks/2d8JP84HNLKhmd6IYOoupQ',
#     'id': '2d8JP84HNLKhmd6IYOoupQ',
#     'is_local': False,
#     'name': 'Trap Queen',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e60314d664f2e19fe693e30acbcb91b9083a787a?cid=85b083e9a83647369e363f8e7cf8158e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2d8JP84HNLKhmd6IYOoupQ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MbrazQE12UdSdFunXcft1'},
#        'href': 'https://api.spotify.com/v1/artists/3MbrazQE12UdSdFunXcft1',
#        'id': '3MbrazQE12UdSdFunXcft1',
#        'name': 'Loren Gray',
#        'type': 'artist',
#        'uri': 'spotify:artist:3MbrazQE12UdSdFunXcft1'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5acYgqkqRhxgbeRzHqIIqv'},
#      'href': 'https://api.spotify.com/v1/albums/5acYgqkqRhxgbeRzHqIIqv',
#      'id': '5acYgqkqRhxgbeRzHqIIqv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b1f28bbbca75aecc31bdd306',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b1f28bbbca75aecc31bdd306',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b1f28bbbca75aecc31bdd306',
#        'width': 64}],
#      'name': 'Queen',
#      'release_date': '2018-12-21',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5acYgqkqRhxgbeRzHqIIqv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MbrazQE12UdSdFunXcft1'},
#       'href': 'https://api.spotify.com/v1/artists/3MbrazQE12UdSdFunXcft1',
#       'id': '3MbrazQE12UdSdFunXcft1',
#       'name': 'Loren Gray',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MbrazQE12UdSdFunXcft1'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 160444,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71821784'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/53b4d9jHQZq89EtQxwUURr'},
#     'href': 'https://api.spotify.com/v1/tracks/53b4d9jHQZq89EtQxwUURr',
#     'id': '53b4d9jHQZq89EtQxwUURr',
#     'is_local': False,
#     'name': 'Queen',
#     'popularity': 62,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:53b4d9jHQZq89EtQxwUURr'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1z4g3DjTBBZKhvAroFlhOM'},
#        'href': 'https://api.spotify.com/v1/artists/1z4g3DjTBBZKhvAroFlhOM',
#        'id': '1z4g3DjTBBZKhvAroFlhOM',
#        'name': 'Red Velvet',
#        'type': 'artist',
#        'uri': 'spotify:artist:1z4g3DjTBBZKhvAroFlhOM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Pe5LGQgU3mmvuRjFMsACV'},
#      'href': 'https://api.spotify.com/v1/albums/6Pe5LGQgU3mmvuRjFMsACV',
#      'id': '6Pe5LGQgU3mmvuRjFMsACV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273830de2e836036f181df598d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02830de2e836036f181df598d0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851830de2e836036f181df598d0',
#        'width': 64}],
#      'name': 'Queendom - The 6th Mini Album',
#      'release_date': '2021-08-16',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:6Pe5LGQgU3mmvuRjFMsACV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1z4g3DjTBBZKhvAroFlhOM'},
#       'href': 'https://api.spotify.com/v1/artists/1z4g3DjTBBZKhvAroFlhOM',
#       'id': '1z4g3DjTBBZKhvAroFlhOM',
#       'name': 'Red Velvet',
#       'type': 'artist',
#       'uri': 'spotify:artist:1z4g3DjTBBZKhvAroFlhOM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 181760,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA302100268'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6SpPr7K4YQ2wp8jU6uOTmQ'},
#     'href': 'https://api.spotify.com/v1/tracks/6SpPr7K4YQ2wp8jU6uOTmQ',
#     'id': '6SpPr7K4YQ2wp8jU6uOTmQ',
#     'is_local': False,
#     'name': 'Queendom',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bef54ce97af1ae3534f3dfeaf34042e28e9b98d0?cid=85b083e9a83647369e363f8e7cf8158e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6SpPr7K4YQ2wp8jU6uOTmQ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2vnB6tuQMaQpORiRdvXF9H'},
#        'href': 'https://api.spotify.com/v1/artists/2vnB6tuQMaQpORiRdvXF9H',
#        'id': '2vnB6tuQMaQpORiRdvXF9H',
#        'name': 'Beach Bunny',
#        'type': 'artist',
#        'uri': 'spotify:artist:2vnB6tuQMaQpORiRdvXF9H'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1lgr82yCJYR5lgsSyxXgBH'},
#      'href': 'https://api.spotify.com/v1/albums/1lgr82yCJYR5lgsSyxXgBH',
#      'id': '1lgr82yCJYR5lgsSyxXgBH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730ec9ae111708f4b8be932d8b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020ec9ae111708f4b8be932d8b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510ec9ae111708f4b8be932d8b',
#        'width': 64}],
#      'name': 'Prom Queen',
#      'release_date': '2018-08-10',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:1lgr82yCJYR5lgsSyxXgBH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2vnB6tuQMaQpORiRdvXF9H'},
#       'href': 'https://api.spotify.com/v1/artists/2vnB6tuQMaQpORiRdvXF9H',
#       'id': '2vnB6tuQMaQpORiRdvXF9H',
#       'name': 'Beach Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:2vnB6tuQMaQpORiRdvXF9H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 136562,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZDA71885746'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6MpCaSIOfqBqbMED4kXgNY'},
#     'href': 'https://api.spotify.com/v1/tracks/6MpCaSIOfqBqbMED4kXgNY',
#     'id': '6MpCaSIOfqBqbMED4kXgNY',
#     'is_local': False,
#     'name': 'Prom Queen',
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d2be52c8b1d36d9b6ed4f3298802bdc93ebd8f9d?cid=85b083e9a83647369e363f8e7cf8158e',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6MpCaSIOfqBqbMED4kXgNY'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ndSXQRalCxfeL0rzd4YXa'},
#        'href': 'https://api.spotify.com/v1/artists/7ndSXQRalCxfeL0rzd4YXa',
#        'id': '7ndSXQRalCxfeL0rzd4YXa',
#        'name': 'Descendants 3 – Cast',
#        'type': 'artist',
#        'uri': 'spotify:artist:7ndSXQRalCxfeL0rzd4YXa'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3xvaSlT4xsyk6lY1ESOspO'},
#        'href': 'https://api.spotify.com/v1/artists/3xvaSlT4xsyk6lY1ESOspO',
#        'id': '3xvaSlT4xsyk6lY1ESOspO',
#        'name': 'Disney',
#        'type': 'artist',
#        'uri': 'spotify:artist:3xvaSlT4xsyk6lY1ESOspO'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
# ...
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 224706,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11802006'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2lxW8vQ9Qjv0qeSQiIBOKJ'},
#     'href': 'https://api.spotify.com/v1/tracks/2lxW8vQ9Qjv0qeSQiIBOKJ',
#     'id': '2lxW8vQ9Qjv0qeSQiIBOKJ',
#     'is_local': False,
#     'name': 'Queen (feat. Quinn XCII)',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b891eb9cfd37947a7d2045ab46fbca12d2c2de50?cid=85b083e9a83647369e363f8e7cf8158e',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:2lxW8vQ9Qjv0qeSQiIBOKJ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/181bsRPaVXVlUKXrxwZfHK'},
#        'href': 'https://api.spotify.com/v1/artists/181bsRPaVXVlUKXrxwZfHK',
#        'id': '181bsRPaVXVlUKXrxwZfHK',
#        'name': 'Megan Thee Stallion',
#        'type': 'artist',
#        'uri': 'spotify:artist:181bsRPaVXVlUKXrxwZfHK'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/26jEIrN7WSAnVQXXUmLRSN'},
#      'href': 'https://api.spotify.com/v1/albums/26jEIrN7WSAnVQXXUmLRSN',
#      'id': '26jEIrN7WSAnVQXXUmLRSN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736cf50daf249842c725cef102',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026cf50daf249842c725cef102',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516cf50daf249842c725cef102',
#        'width': 64}],
#      'name': 'Tina Snow',
#      'release_date': '2018-12-21',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:26jEIrN7WSAnVQXXUmLRSN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/181bsRPaVXVlUKXrxwZfHK'},
#       'href': 'https://api.spotify.com/v1/artists/181bsRPaVXVlUKXrxwZfHK',
#       'id': '181bsRPaVXVlUKXrxwZfHK',
#       'name': 'Megan Thee Stallion',
#       'type': 'artist',
#       'uri': 'spotify:artist:181bsRPaVXVlUKXrxwZfHK'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 222752,
#     'explicit': True,
#     'external_ids': {'isrc': 'USXQS1821739'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2GbS8QZToLioxL8XMEwX3P'},
#     'href': 'https://api.spotify.com/v1/tracks/2GbS8QZToLioxL8XMEwX3P',
#     'id': '2GbS8QZToLioxL8XMEwX3P',
#     'is_local': False,
#     'name': 'Cognac Queen',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0b78c9eaf0d9c8d369a46cad5e08e36b5a96cfec?cid=85b083e9a83647369e363f8e7cf8158e',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:2GbS8QZToLioxL8XMEwX3P'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#        'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#        'id': '1dfeR4HaWDbWqFHLkxsg1d',
#        'name': 'Queen',
#        'type': 'artist',
#        'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7oHaj9jkWHByziQsqGAb8V'},
#      'href': 'https://api.spotify.com/v1/albums/7oHaj9jkWHByziQsqGAb8V',
#      'id': '7oHaj9jkWHByziQsqGAb8V',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734aab69127abbdced0dec07e0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024aab69127abbdced0dec07e0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514aab69127abbdced0dec07e0',
#        'width': 64}],
#      'name': 'The Works (Deluxe Remastered Version)',
#      'release_date': '1984-02-27',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:7oHaj9jkWHByziQsqGAb8V'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#       'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#       'id': '1dfeR4HaWDbWqFHLkxsg1d',
#       'name': 'Queen',
#       'type': 'artist',
#       'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 348226,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71029623'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1HmzAZUvhQLhLo2z3ocpZI'},
#     'href': 'https://api.spotify.com/v1/tracks/1HmzAZUvhQLhLo2z3ocpZI',
#     'id': '1HmzAZUvhQLhLo2z3ocpZI',
#     'is_local': False,
#     'name': 'Radio Ga Ga - Remastered 2011',
#     'popularity': 60,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1HmzAZUvhQLhLo2z3ocpZI'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ycxRkcZ67ALN3GQJ57Vig'},
#        'href': 'https://api.spotify.com/v1/artists/3ycxRkcZ67ALN3GQJ57Vig',
#        'id': '3ycxRkcZ67ALN3GQJ57Vig',
#        'name': 'Masego',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ycxRkcZ67ALN3GQJ57Vig'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2wqG59dVVQlJaxoO7N0LJt'},
#      'href': 'https://api.spotify.com/v1/albums/2wqG59dVVQlJaxoO7N0LJt',
#      'id': '2wqG59dVVQlJaxoO7N0LJt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f1814f1b76df2fa196e4f45e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f1814f1b76df2fa196e4f45e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f1814f1b76df2fa196e4f45e',
#        'width': 64}],
#      'name': 'Lady Lady',
#      'release_date': '2018-09-07',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2wqG59dVVQlJaxoO7N0LJt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ycxRkcZ67ALN3GQJ57Vig'},
#       'href': 'https://api.spotify.com/v1/artists/3ycxRkcZ67ALN3GQJ57Vig',
#       'id': '3ycxRkcZ67ALN3GQJ57Vig',
#       'name': 'Masego',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ycxRkcZ67ALN3GQJ57Vig'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IEnjZsVDEPKUTxNinyqba'},
#       'href': 'https://api.spotify.com/v1/artists/2IEnjZsVDEPKUTxNinyqba',
#       'id': '2IEnjZsVDEPKUTxNinyqba',
#       'name': 'Tiffany Gouché',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IEnjZsVDEPKUTxNinyqba'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 188053,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZD5H1800023'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5tkR9JkBj3Ueeo8W4k8IZD'},
#     'href': 'https://api.spotify.com/v1/tracks/5tkR9JkBj3Ueeo8W4k8IZD',
#     'id': '5tkR9JkBj3Ueeo8W4k8IZD',
#     'is_local': False,
#     'name': 'Queen Tings',
#     'popularity': 57,
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:5tkR9JkBj3Ueeo8W4k8IZD'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Queen&type=track&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 10509}}

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
len(results['tracks']['items'])
# Out:
# 50

# %%
results['tracks']['items'][5].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][5]['name']
# Out:
# 'Queen'

# %%
results['tracks']['items'][5]['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/track/53b4d9jHQZq89EtQxwUURr'}

# %% [markdown]
# ## Find a single song:

# %%
results['tracks']['items'][5]['uri']
# Out:
# 'spotify:track:53b4d9jHQZq89EtQxwUURr'

# %%
results['tracks']['items'][0]['id']
# Out:
# '1xyUCr7dIJYaUaaiDf4Q1L'

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri" or an "id".
#
# - The id is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The uri contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The url is a link to the song on the Spotify web player.
#
# - We'll use the uri in this code-along, but feel free to use whatever you think fits best your needs.

# %% [markdown]
# ## Activity 1

# %% [markdown]
# Searching multiple artists
#
# create a list of my_20_artists eg
#
# artists = ["Dire Straits", "Queen", "Ella Fitzgerald"....]
#
# Loop over your 20 favorite artists and their results to the list.
#
# Create a function that takes a list of artist names and return their 50 first appearances as a dictionary.

# %%
my_20_artists=['Ella Fitzgerald','Etta James','Louis Armstrong','Cole Porter','Billie Holiday', 'Dinah Washington', 'Queen', 'Beardyman','Lea Dasandre','Gregory Porter', 'Errol Linton', 'Nubya Garcia', 'Roxette', 'Prince', 'Ellie Goulding', 'Tracy Chapman', 'Fleetwood Mac', 'Morcheeba', 'Status Quo', 'The Doors']

# %%
len(my_20_artists)
# Out:
# 20

# %%
my_artists_tracks[0]['tracks']['items'][49]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5V0MlUE1Bft0mbLlND7FJz'},
#     'href': 'https://api.spotify.com/v1/artists/5V0MlUE1Bft0mbLlND7FJz',
#     'id': '5V0MlUE1Bft0mbLlND7FJz',
#     'name': 'Ella Fitzgerald',
#     'type': 'artist',
#     'uri': 'spotify:artist:5V0MlUE1Bft0mbLlND7FJz'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4HfTyzIioLsV8YpFvY7Iga'},
#   'href': 'https://api.spotify.com/v1/albums/4HfTyzIioLsV8YpFvY7Iga',
#   'id': '4HfTyzIioLsV8YpFvY7Iga',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27321899f56f7942085625eb6ba',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0221899f56f7942085625eb6ba',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485121899f56f7942085625eb6ba',
#     'width': 64}],
#   'name': 'The Complete Decca Singles Vol. 2: 1939-1941',
#   'release_date': '2017-04-14',
#   'release_date_precision': 'day',
#   'total_tracks': 50,
#   'type': 'album',
#   'uri': 'spotify:album:4HfTyzIioLsV8YpFvY7Iga'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/02UotVhmqPg91twSGAwSgR'},
#    'href': 'https://api.spotify.com/v1/artists/02UotVhmqPg91twSGAwSgR',
#    'id': '02UotVhmqPg91twSGAwSgR',
#    'name': 'Ella Fitzgerald and Her Famous Orchestra',
#    'type': 'artist',
#    'uri': 'spotify:artist:02UotVhmqPg91twSGAwSgR'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 2,
#  'duration_ms': 176030,
#  'explicit': False,
#  'external_ids': {'isrc': 'USMC14169785'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/7g2xOQm7ZmiJXuKyNVKFq5'},
#  'href': 'https://api.spotify.com/v1/tracks/7g2xOQm7ZmiJXuKyNVKFq5',
#  'id': '7g2xOQm7ZmiJXuKyNVKFq5',
#  'is_local': False,
#  'name': 'This Love Of Mine',
#  'popularity': 19,
#  'preview_url': None,
#  'track_number': 19,
#  'type': 'track',
#  'uri': 'spotify:track:7g2xOQm7ZmiJXuKyNVKFq5'}

# %%
def artist_to_track_dict(artist_list):
    return {artist:sp.search(q=artist,limit=50) for artist in artist_list}

# %%
len(artist_to_track_dict(my_20_artists))
# Out:
# 20

# %%
my_dict=artist_to_track_dict(my_20_artists)

# %%
my_dict.keys()
# Out:
# dict_keys(['Ella Fitzgerald', 'Etta James', 'Louis Armstrong', 'Cole Porter', 'Billie Holiday', 'Dinah Washington', 'Queen', 'Beardyman', 'Lea Dasandre', 'Gregory Porter', 'Errol Linton', 'Nubya Garcia', 'Roxette', 'Prince', 'Ellie Goulding', 'Tracy Chapman', 'Fleetwood Mac', 'Morcheeba', 'Status Quo', 'The Doors'])

# %%
my_dict['Ella Fitzgerald'].keys()
# Out:
# dict_keys(['tracks'])

# %%
my_dict['Ella Fitzgerald']['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
my_dict['Ella Fitzgerald']['tracks']['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5V0MlUE1Bft0mbLlND7FJz'},
#   'href': 'https://api.spotify.com/v1/artists/5V0MlUE1Bft0mbLlND7FJz',
#   'id': '5V0MlUE1Bft0mbLlND7FJz',
#   'name': 'Ella Fitzgerald',
#   'type': 'artist',
#   'uri': 'spotify:artist:5V0MlUE1Bft0mbLlND7FJz'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/19eLuQmk9aCobbVDHc6eek'},
#   'href': 'https://api.spotify.com/v1/artists/19eLuQmk9aCobbVDHc6eek',
#   'id': '19eLuQmk9aCobbVDHc6eek',
#   'name': 'Louis Armstrong',
#   'type': 'artist',
#   'uri': 'spotify:artist:19eLuQmk9aCobbVDHc6eek'}]

# %%
my_dict['Ella Fitzgerald']['tracks']['items'][0]['name']
# Out:
# 'Dream A Little Dream Of Me - Single Version'

# %%
my_dict['Ella Fitzgerald']['tracks']['items'][0]['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/track/78MI7mu1LV1k4IA2HzKmHe'}

# %%
my_dict['Ella Fitzgerald']['tracks']['items'][0]['uri']
# Out:
# 'spotify:track:78MI7mu1LV1k4IA2HzKmHe'

# %%
my_dict['Ella Fitzgerald']['tracks']['items'][0]['id']
# Out:
# '78MI7mu1LV1k4IA2HzKmHe'

# %%
#experiment : 
three_artists = ["Dire Straits", "Queen", "Ella Fitzgerald"]

# %%
len(artist_to_track_dict(three_artists))
# Out:
# 3

# %% [markdown]
# ## look at artists and albums from first query results

# %%
results['tracks']['items'][13].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][13]['artists'][0]['name']
# Out:
# 'Queen'

# %%
results['tracks']['items'][13]['album'].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
results['tracks']['items'][13]['album']['name']
# Out:
# 'Sheer Heart Attack (Deluxe Remastered Version)'

# %%
results['tracks']['items'][13]['album']['artists'][0]['name']
# Out:
# 'Queen'

# %% [markdown]
# ## Activity 2

# %% [markdown]
# Function to get the artists involved in a song:
#
# Function to get the "id's" of the artists from a song:

# %%
results = sp.track('78MI7mu1LV1k4IA2HzKmHe', market='GB')

# %%
results.keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5V0MlUE1Bft0mbLlND7FJz'},
#     'href': 'https://api.spotify.com/v1/artists/5V0MlUE1Bft0mbLlND7FJz',
#     'id': '5V0MlUE1Bft0mbLlND7FJz',
#     'name': 'Ella Fitzgerald',
#     'type': 'artist',
#     'uri': 'spotify:artist:5V0MlUE1Bft0mbLlND7FJz'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1y5KGkUKO0NG32MhIIagCA'},
#   'href': 'https://api.spotify.com/v1/albums/1y5KGkUKO0NG32MhIIagCA',
#   'id': '1y5KGkUKO0NG32MhIIagCA',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27388ab39d88260598e95ebf5f4',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0288ab39d88260598e95ebf5f4',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485188ab39d88260598e95ebf5f4',
#     'width': 64}],
#   'name': 'Love, Ella',
#   'release_date': '2007-05-03',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'type': 'album',
#   'uri': 'spotify:album:1y5KGkUKO0NG32MhIIagCA'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5V0MlUE1Bft0mbLlND7FJz'},
#    'href': 'https://api.spotify.com/v1/artists/5V0MlUE1Bft0mbLlND7FJz',
#    'id': '5V0MlUE1Bft0mbLlND7FJz',
#    'name': 'Ella Fitzgerald',
#    'type': 'artist',
#    'uri': 'spotify:artist:5V0MlUE1Bft0mbLlND7FJz'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/19eLuQmk9aCobbVDHc6eek'},
#    'href': 'https://api.spotify.com/v1/artists/19eLuQmk9aCobbVDHc6eek',
#    'id': '19eLuQmk9aCobbVDHc6eek',
#    'name': 'Louis Armstrong',
#    'type': 'artist',
#    'uri': 'spotify:artist:19eLuQmk9aCobbVDHc6eek'}],
#  'disc_number': 1,
#  'duration_ms': 185160,
#  'explicit': False,
#  'external_ids': {'isrc': 'USMC15076750'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/78MI7mu1LV1k4IA2HzKmHe'},
#  'href': 'https://api.spotify.com/v1/tracks/78MI7mu1LV1k4IA2HzKmHe',
#  'id': '78MI7mu1LV1k4IA2HzKmHe',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Dream A Little Dream Of Me - Single Version',
#  'popularity': 62,
#  'preview_url': None,
#  'track_number': 4,
#  'type': 'track',
#  'uri': 'spotify:track:78MI7mu1LV1k4IA2HzKmHe'}

# %%
type(results)
# Out:
# dict

# %%
range(len(results['artists']))
# Out:
# range(0, 2)

# %%
results['artists'][0]['id']
# Out:
# '5V0MlUE1Bft0mbLlND7FJz'

# %%
results['artists'][0]['name']
# Out:
# 'Ella Fitzgerald'

# %%
import pandas as pd

# %%
import pandas as pd
#get artist date from one song id 
artist_names=[]
artist_ids=[]
def get_artist_from_track(track_id):
    search=sp.track(track_id, market='GB')
    listofartists=search['artists']
    for a in range(len(listofartists)):
        artist_name=listofartists[a]['name']
        artist_names.append(artist_name)
        artist_id=listofartists[a]['id']
        artist_ids.append(artist_id)
    artists_df=pd.DataFrame({"artist":artist_names,"id":artist_ids})
    return artists_df

# %%
get_artist_from_track('78MI7mu1LV1k4IA2HzKmHe')
# Out:
#             artist                      id
# 0  Ella Fitzgerald  5V0MlUE1Bft0mbLlND7FJz
# 1  Louis Armstrong  19eLuQmk9aCobbVDHc6eek

# %%
# apply the above to a dictionary of tracks - first get the song ids 
song_ids=[]
def song_ids_from_dict_tracks(my_artist_tracks_dict):
    for key,value in my_artist_tracks_dict.items():
        songs=my_artist_tracks_dict[key]['tracks']['items']
        for i in range(len(songs)):
            song_id=songs[i]['id']
            song_ids.append(song_id)

# %%
my_artist_tracks_dict=artist_to_track_dict(three_artists)

# %%
song_ids_from_dict_tracks(my_artist_tracks_dict)

# %%
song_ids

# %%
len(song_ids)
# Out:
# 150

# %%
# now test tracks method to retrieve artists from list of songs 
# maximum is 50 so we will take a cut of songs 
fifty_songs=song_ids[0:30]
track_list=sp.tracks(fifty_songs, market='GB') # maximum is 50 so we will take the first 50 songs

# %%
range(len(track_list['tracks']))
# Out:
# range(0, 30)

# %%
(track_list['tracks'])[0]['artists'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/0WwSkZ7LtFUFjGjMZBMt6T'},
#  'href': 'https://api.spotify.com/v1/artists/0WwSkZ7LtFUFjGjMZBMt6T',
#  'id': '0WwSkZ7LtFUFjGjMZBMt6T',
#  'name': 'Dire Straits',
#  'type': 'artist',
#  'uri': 'spotify:artist:0WwSkZ7LtFUFjGjMZBMt6T'}

# %%
artist_names=[]
artist_ids=[]
def get_artist_from_track_list(songs):
    search=sp.tracks(songs, market='GB')
    all_tracks_data=search['tracks']
    for t in range(len(all_tracks_data)):
        artist_record=search['tracks'][t]['artists']
        for a in range(len(artist_record)):
            artist_name=artist_record[a]['name']
            artist_names.append(artist_name)
            artist_id=artist_record[a]['id']
            artist_ids.append(artist_id)
    artists_df=pd.DataFrame({"artist":artist_names,"id":artist_ids})
    return artists_df

# %%
get_artist_from_track_list(fifty_songs)
# Out:
#             artist                      id
# 0     Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 1     Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 2     Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 3     Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 4     Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 5     Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 6     Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 7       Horrorshow  4sL6dLwItg7ppqj4NwEQr6
# 8     Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 9            Blake  7dJyMvpENq3xerjTPtwZvF
# 10    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 11    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 12    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 13    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 14    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 15    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 16    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 17    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 18    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 19    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 20    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 21   Mark Knopfler  0FI0kxP0BWurTz8cB8BBug
# 22  Emmylou Harris  5s6TJEuHTr9GR894wc6VfP
# 23    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 24    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 25    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 26    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 27    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 28    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 29    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T
# 30    Dire Straits  0WwSkZ7LtFUFjGjMZBMt6T

# %% [markdown]
# ## Playlists
# - We will need to collect a "database" of songs. Playlists are a good way to access relatively large amounts of songs.

# %%
playlist_2 = sp.user_playlist_tracks("Chris Connor", "6IUloum8FQGE1PrObJZavG")

#https://open.spotify.com/playlist/6IUloum8FQGE1PrObJZavG?si=7420a44dca53435a - copied from spotify

# %%
playlist_2["total"]
# Out:
# 100

# %%
playlist_2['items'][0]['track']['id']
# Out:
# '6kopmMZiyLmw7h66uXcXR7'

# %% [markdown]
# ## Activity 3
# - Function to extract all songs ID, name, artist from a playlist
# - Output: Dictionary with key: song ID and values: list(song name, artist).

# %%
songs = {
  track["track"]["id"]: [track["track"]["name"], 
  track["track"]["artists"][0]["name"]] 
  for track in playlist_2["items"]
}

# %%
playlist_trackIDs=[]

# %%
def songsfromplaylist(username,playlist_id):
    playlist=sp.user_playlist_tracks(username, playlist_id)
    for item in playlist['items']:
        playlist_trackIDs.append(item['track']['id'])

# %%
songsfromplaylist("Chris Connor", "6IUloum8FQGE1PrObJZavG")

# %%
playlist_trackIDs
# Out:
# ['0KT6DLAELYSbgfUemzwGPX',
#  '3KhoIbIPMmoGthbBAPxgOK',
#  '71NJqORRmwlcZSLk0VsFjU',
#  '4aPyWHfUOpRucgvJ5riGvq',
#  '0GA6S7nyMRn1w1S5o1LGFX',
#  '0pMUR7Uvp6vxlbG0qBFvgM',
#  '4YaHN0QNmlj6gagyodfT8K',
#  '3e9L9HiHKcfYLAga28Vmcf',
#  '0OSAJEA0ekX6pr2nuiPzX7',
#  '4UfupbARPxljVkBmuZlJnY',
#  '2JmH5UJ6TwTCg05OBeIa7b',
#  '2Bw2MQa6qHoHUxKM9c6bds',
#  '1BeZ3neH8aQioMKccVHdS9',
#  '38TAtcKt2mSIKV5aq9eVtL',
#  '5k68G0l4XbYskcczLtgPLs',
#  '5dZ2tajLu1kwfLGfjEpr8p',
#  '62boy9i5H49Fk2FUbna3co',
#  '3oVnbdWg48ZrmsUAQQUKbU',
#  '1zEru7ZuZFzkjRoUDvsWQ6',
#  '0Wx8C0yiq0Djk9EiPktvXv',
#  '5mAh5J4w6BEZkajB1M7XrB',
#  '5oUH9Rl2PdFklGKc9kMBkE',
#  '1rj8sTws7tXmgI8X1GMgKF',
#  '1xNcBAoUw8Hz6LqK2jt4Ff',
#  '6KzkqZqhUBEsWYJJa2aBOd',
#  '4Z08iSbr5wXWsKUaY7BrsG',
#  '6W7SV30GzW4utRTcMF8laV',
#  '2h5z2TzryGt3DoeCCdQwHs',
#  '37a8EdVw7VpAlRG4oASxIm',
#  '0YqdtgkhhcbzWQuBmN0Lik',
#  '6qjc1goYnjYrNqOXUiJgRj',
#  '2aAlGJc0REgny9znAOaBsF',
#  '1loMHOGpWEgh1cFvpoSZf0',
#  '2KO9yJSsYzPlYTWkOY2nTb',
#  '6WPH6nvXF7F7233pTNXJJx',
#  '1p1qbyBOklYJI6EC69Yd1a',
#  '3nUOnATHktg7VW5TtWeJnd',
#  '0HnaHNLndwgiIOL2XBRnL4',
#  '2U4gDQIMt74zIFIrUQksUx',
#  '50v2JhRDBbQa7TpNIV3zmp',
#  '4zrl5YGi2OqMar45Kdn4BM',
#  '2lKNRgB2pDAnmGvi0myoLb',
#  '6Ss1QOGzn0iG8hrRRSGrr9',
#  '3ZwTdhV7SLapBoEXDOLxI5',
#  '14IM6OZDLGfkaJNlswwNSg',
#  '5ho5w0CgWmTGxuo2Ehemyc',
#  '5eDQwsl2p2QivtXhmyM2rX',
#  '4Zy2QYNvzenQm1BPKh6dK8',
#  '2gzuyKcPVjRz8D55cNtm3m',
#  '0xmHsJHjqMYB1lIs9J5zP5',
#  '1SjJZewpXEHRuXn7RRszQ5']

# %%
playlist=sp.user_playlist_tracks("Chris Connor", "6IUloum8FQGE1PrObJZavG")
songs = {
  track["track"]["id"]: [track["track"]["name"], 
  track["track"]["artists"][0]["name"]] 
  for track in playlist["items"]
}

# %%
songs
# Out:
# {'0KT6DLAELYSbgfUemzwGPX': ['Heaven', 'DJ Sammy'],
#  '3KhoIbIPMmoGthbBAPxgOK': ['Castles In The Sky - Radio Mix', 'Ian van Dahl'],
#  '71NJqORRmwlcZSLk0VsFjU': ['Pretty Green Eyes - Radio Edit', 'Ultrabeat'],
#  '4aPyWHfUOpRucgvJ5riGvq': ['Pretty Green Eyes', 'Ultrabeat'],
#  '0GA6S7nyMRn1w1S5o1LGFX': ['At Night - Original Club Mix', 'Shakedown'],
#  '0pMUR7Uvp6vxlbG0qBFvgM': ['Better Off Alone', 'Alice Deejay'],
#  '4YaHN0QNmlj6gagyodfT8K': ['Forever', 'Dee Dee'],
#  '3e9L9HiHKcfYLAga28Vmcf': ['Something', 'Lasgo'],
#  '0OSAJEA0ekX6pr2nuiPzX7': ['Rapture (feat.Nadia Ali)', 'iio'],
#  '4UfupbARPxljVkBmuZlJnY': ['Starlight - Radio Edit', 'The Supermen Lovers'],
#  '2JmH5UJ6TwTCg05OBeIa7b': ['Another Chance - Radio Edit', 'Roger Sanchez'],
#  '2Bw2MQa6qHoHUxKM9c6bds': ["U Don't Know Me (feat. Duane Harden)",
#   'Armand Van Helden'],
#  '1BeZ3neH8aQioMKccVHdS9': ['Finally', 'Kings Of Tomorrow'],
#  '38TAtcKt2mSIKV5aq9eVtL': ['Be Cool - Radio Edit', 'Paffendorf'],
#  '5k68G0l4XbYskcczLtgPLs': ['Hide U', 'Kosheen'],
#  '5dZ2tajLu1kwfLGfjEpr8p': ['The Way - Svenson & Gielen Radio Edit',
#   'Divine Inspiration'],
#  '62boy9i5H49Fk2FUbna3co': ["You're a Superstar - Radio Edit", 'Love Inc.'],
#  '3oVnbdWg48ZrmsUAQQUKbU': ["Silence (feat. Sarah McLachlan) - DJ Tiësto's In Search of Sunrise Edit",
#   'Delerium'],
#  '1zEru7ZuZFzkjRoUDvsWQ6': ['Loneliness - Radio Cut', 'Tomcraft'],
#  '0Wx8C0yiq0Djk9EiPktvXv': ['All I Do (Radio Edit)', 'Cleptomaniacs'],
#  '5mAh5J4w6BEZkajB1M7XrB': ["Lola's Theme - Radio Edit", 'The Shapeshifters'],
#  '5oUH9Rl2PdFklGKc9kMBkE': ['Flawless - Phunk Investigation Club', 'Ones'],
#  '1rj8sTws7tXmgI8X1GMgKF': ['Make Luv (Radio Version)', 'Room 5'],
#  '1xNcBAoUw8Hz6LqK2jt4Ff': ['Call on Me - Radio Mix', 'Eric Prydz'],
#  '6KzkqZqhUBEsWYJJa2aBOd': ['The Weekend - Radio Edit', 'Michael Gray'],
#  '4Z08iSbr5wXWsKUaY7BrsG': ['Do You Know (I Go Crazy)', 'Angel City'],
#  '6W7SV30GzW4utRTcMF8laV': ['Flashdance (Original Mix)', 'Deep Dish'],
#  '2h5z2TzryGt3DoeCCdQwHs': ['Falling Stars', 'Sunset Strippers'],
#  '37a8EdVw7VpAlRG4oASxIm': ['Out of Touch - Radio Edit', 'Uniting Nations'],
#  '0YqdtgkhhcbzWQuBmN0Lik': ['I Like The Way - Radio Edit', 'Bodyrockers'],
#  '6qjc1goYnjYrNqOXUiJgRj': ['So Much Love To Give (Radio Edit)',
#   'Freeloaders'],
#  '2aAlGJc0REgny9znAOaBsF': ["Don't Give Up", 'Chicane'],
#  '1loMHOGpWEgh1cFvpoSZf0': ['Good Luck', 'Basement Jaxx'],
#  '2KO9yJSsYzPlYTWkOY2nTb': ['Boogie 2Nite - Seamus Haji Big Love Edit',
#   'Booty Luv'],
#  '6WPH6nvXF7F7233pTNXJJx': ['My My My', 'Armand Van Helden'],
#  '1p1qbyBOklYJI6EC69Yd1a': ["Put 'Em High", 'Therese'],
#  '3nUOnATHktg7VW5TtWeJnd': ["My Feeling (Daddy'S Prime Time Edit)",
#   'Junior Jack'],
#  '0HnaHNLndwgiIOL2XBRnL4': ['Sun Is Shining - Radio De Luxe Mix',
#   'Funkstar De Luxe'],
#  '2U4gDQIMt74zIFIrUQksUx': ['I Wanna Be U', 'Chocolate Puma'],
#  '50v2JhRDBbQa7TpNIV3zmp': ['Somebody to Love - Main Club Mix',
#   'Boogie Pimps'],
#  '4zrl5YGi2OqMar45Kdn4BM': ['Take Me To The Clouds Above - LMC Vs. U2 / Radio Edit',
#   'LMC'],
#  '2lKNRgB2pDAnmGvi0myoLb': ['I See Girls - Tom Neville Radio Edit',
#   'Studio B.'],
#  '6Ss1QOGzn0iG8hrRRSGrr9': ["It Just Won't Do - Radio Edit", 'Tim Deluxe'],
#  '3ZwTdhV7SLapBoEXDOLxI5': ['Stupidisco', 'Junior Jack'],
#  '14IM6OZDLGfkaJNlswwNSg': ['Love Story (Radio Edit)', 'Layo & Bushwacka!'],
#  '5ho5w0CgWmTGxuo2Ehemyc': ['Party All The Time', 'Sharam'],
#  '5eDQwsl2p2QivtXhmyM2rX': ['Your Body - UK Radio Edit', 'Tom Novy'],
#  '4Zy2QYNvzenQm1BPKh6dK8': ['Salsoul Nugget (If U Wanna)', 'M&S'],
#  '2gzuyKcPVjRz8D55cNtm3m': ['Point of View - Radio Edit', 'DB Boulevard'],
#  '0xmHsJHjqMYB1lIs9J5zP5': ['Shine - The Lovefreekz Radio Edit',
#   'The Lovefreekz'],
#  '1SjJZewpXEHRuXn7RRszQ5': ["King of My Castle - Roy Malone's King Radio Edit",
#   'Wamdue Project']}

# %% [markdown]
# ## Function to extract just the uri's:

# %%
playlist_2['items'][0]['track']['uri']
# Out:
# 'spotify:track:6kopmMZiyLmw7h66uXcXR7'

# %%
def uris_from_playlist(my_playlist_id,playlist_owner):
    
    my_playlist_uris=[]
    for item in playlist['items']:
        my_playlist_uris.append(item['track']['uri'])
    return my_playlist_uris

# %%
uris_from_playlist('6PQLNIY9wZFZAygGzgH5hc','jamesacaster')
# Out:
# ['spotify:track:0KT6DLAELYSbgfUemzwGPX',
#  'spotify:track:3KhoIbIPMmoGthbBAPxgOK',
#  'spotify:track:71NJqORRmwlcZSLk0VsFjU',
#  'spotify:track:4aPyWHfUOpRucgvJ5riGvq',
#  'spotify:track:0GA6S7nyMRn1w1S5o1LGFX',
#  'spotify:track:0pMUR7Uvp6vxlbG0qBFvgM',
#  'spotify:track:4YaHN0QNmlj6gagyodfT8K',
#  'spotify:track:3e9L9HiHKcfYLAga28Vmcf',
#  'spotify:track:0OSAJEA0ekX6pr2nuiPzX7',
#  'spotify:track:4UfupbARPxljVkBmuZlJnY',
#  'spotify:track:2JmH5UJ6TwTCg05OBeIa7b',
#  'spotify:track:2Bw2MQa6qHoHUxKM9c6bds',
#  'spotify:track:1BeZ3neH8aQioMKccVHdS9',
#  'spotify:track:38TAtcKt2mSIKV5aq9eVtL',
#  'spotify:track:5k68G0l4XbYskcczLtgPLs',
#  'spotify:track:5dZ2tajLu1kwfLGfjEpr8p',
#  'spotify:track:62boy9i5H49Fk2FUbna3co',
#  'spotify:track:3oVnbdWg48ZrmsUAQQUKbU',
#  'spotify:track:1zEru7ZuZFzkjRoUDvsWQ6',
#  'spotify:track:0Wx8C0yiq0Djk9EiPktvXv',
#  'spotify:track:5mAh5J4w6BEZkajB1M7XrB',
#  'spotify:track:5oUH9Rl2PdFklGKc9kMBkE',
#  'spotify:track:1rj8sTws7tXmgI8X1GMgKF',
#  'spotify:track:1xNcBAoUw8Hz6LqK2jt4Ff',
#  'spotify:track:6KzkqZqhUBEsWYJJa2aBOd',
#  'spotify:track:4Z08iSbr5wXWsKUaY7BrsG',
#  'spotify:track:6W7SV30GzW4utRTcMF8laV',
#  'spotify:track:2h5z2TzryGt3DoeCCdQwHs',
#  'spotify:track:37a8EdVw7VpAlRG4oASxIm',
#  'spotify:track:0YqdtgkhhcbzWQuBmN0Lik',
#  'spotify:track:6qjc1goYnjYrNqOXUiJgRj',
#  'spotify:track:2aAlGJc0REgny9znAOaBsF',
#  'spotify:track:1loMHOGpWEgh1cFvpoSZf0',
#  'spotify:track:2KO9yJSsYzPlYTWkOY2nTb',
#  'spotify:track:6WPH6nvXF7F7233pTNXJJx',
#  'spotify:track:1p1qbyBOklYJI6EC69Yd1a',
#  'spotify:track:3nUOnATHktg7VW5TtWeJnd',
#  'spotify:track:0HnaHNLndwgiIOL2XBRnL4',
#  'spotify:track:2U4gDQIMt74zIFIrUQksUx',
#  'spotify:track:50v2JhRDBbQa7TpNIV3zmp',
#  'spotify:track:4zrl5YGi2OqMar45Kdn4BM',
#  'spotify:track:2lKNRgB2pDAnmGvi0myoLb',
#  'spotify:track:6Ss1QOGzn0iG8hrRRSGrr9',
#  'spotify:track:3ZwTdhV7SLapBoEXDOLxI5',
#  'spotify:track:14IM6OZDLGfkaJNlswwNSg',
#  'spotify:track:5ho5w0CgWmTGxuo2Ehemyc',
#  'spotify:track:5eDQwsl2p2QivtXhmyM2rX',
#  'spotify:track:4Zy2QYNvzenQm1BPKh6dK8',
#  'spotify:track:2gzuyKcPVjRz8D55cNtm3m',
#  'spotify:track:0xmHsJHjqMYB1lIs9J5zP5',
#  'spotify:track:1SjJZewpXEHRuXn7RRszQ5']

# %% [markdown]
# ## Pagination
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
playlist = sp.user_playlist_tracks("SarahWitheridge", "3UVNqcek0Hg8ne1ijJn9kc")

# %%
playlist['total']
# Out:
# 2619

# %%
playlist['next']
# Out:
# 'https://api.spotify.com/v1/playlists/3UVNqcek0Hg8ne1ijJn9kc/tracks?offset=100&limit=100&additional_types=track'

# %%
len(playlist['items']) # here we can see the limit of 100 records
# Out:
# 100

# %%
def get_playlist_tracks_long(user_id,playlist_id):
    results=sp.user_playlist_tracks(user_id,playlist_id)
    tracks=results['items']
    while results['next']:
        results=sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
all_tracks=get_playlist_tracks_long("SarahWitheridge", "3UVNqcek0Hg8ne1ijJn9kc")

# %%
len(all_tracks)
# Out:
# 2619

# %% [markdown]
# ## Audio features
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %%
playlist = sp.user_playlist_tracks("sianedav", "12in060ErlfyPEfpGTJdaw") # 10 song playlist

# %%
spaceplaylist=[]
for item in playlist['items']:
    spaceplaylist.append(item['track']['id'])

# %%
audio_feat_space=sp.audio_features(tracks=spaceplaylist)

# %%
len(audio_feat_space)
# Out:
# 10

# %% [markdown]
# ## Searching the audio features for a song
# When the user inputs a song, you are gonna want to retrieve the audio features of that song. How to do it?
#
# Search the user input using the sp.search() function. This function works similarly to the "search" bar on the spotify app - using Spotify's intelligent search engine. That means that it can handle names of any songs or artists - even certain typos.
#
# Find the uri of the song that the API gives you back.
#
# Use sp.audio_features to retrieve the audio features of the song.

# %%
results = sp.search(q=input('your song is '),limit=1, type='track')
# Out:
# your song is lady in red

# %%
name=results['tracks']['items'][0]['name']

# %%
artist=results['tracks']['items'][0]["artists"][0]["name"]

# %%
uri = results['tracks']['items'][0]['uri']

# %%
audio_feat_inputsong=sp.audio_features(tracks=uri)

# %%
audio_feat_inputsong
# Out:
# [{'danceability': 0.548,
#   'energy': 0.294,
#   'key': 10,
#   'loudness': -17.112,
#   'mode': 1,
#   'speechiness': 0.0333,
#   'acousticness': 0.332,
#   'instrumentalness': 3.34e-06,
#   'liveness': 0.0392,
#   'valence': 0.491,
#   'tempo': 76.698,
#   'type': 'audio_features',
#   'id': '1GeNWyZtCHbcp3ZWp8GTOO',
#   'uri': 'spotify:track:1GeNWyZtCHbcp3ZWp8GTOO',
#   'track_href': 'https://api.spotify.com/v1/tracks/1GeNWyZtCHbcp3ZWp8GTOO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1GeNWyZtCHbcp3ZWp8GTOO',
#   'duration_ms': 256173,
#   'time_signature': 4}]

# %%
audio_feat_dict=audio_feat_inputsong[0]

# %%
af_df=pd.DataFrame.from_dict([audio_feat_dict])

# %%
af_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.548   0.294   10   -17.112     1       0.0333         0.332
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0          0.000003    0.0392    0.491  76.698  audio_features
#
#                        id                                   uri  \
# 0  1GeNWyZtCHbcp3ZWp8GTOO  spotify:track:1GeNWyZtCHbcp3ZWp8GTOO
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1GeNWyZtCHbc...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1GeN...       256173
#
#    time_signature
# 0               4

# %%
af_df['song_name']=results['tracks']['items'][0]['name']
af_df['1startist']=results['tracks']['items'][0]["artists"][0]["name"]

# %%
af_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.548   0.294   10   -17.112     1       0.0333         0.332
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0          0.000003    0.0392    0.491  76.698  audio_features
#
#                        id                                   uri  \
# 0  1GeNWyZtCHbcp3ZWp8GTOO  spotify:track:1GeNWyZtCHbcp3ZWp8GTOO
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1GeNWyZtCHbc...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1GeN...       256173
#
#    time_signature        song_name       1startist
# 0               4  The Lady In Red  Chris de Burgh

# %% [markdown]
# ## Lab: Create your collection of songs & audio features
# To move forward witht the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster.
#
# The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %% [markdown]
# #create a list of 20 artist
# - Create a list and assign it to a variable named my_20_artists.
# - Loop over your 20 favorite artists and their results to the list.
# - Create a function that takes a list of artist names and return their 50 first appearances as a dictionary.

# %% [markdown]
# ### START HERE TO COMPLETE THE EXERCISE

# %%
len(my_20_artists)
# Out:
# 20

# %%
my_artists_tracks = []
for artist in my_20_artists:
    my_artists_tracks.append(sp.search(q={artist}, limit=50))

# %%
len(my_artists_tracks)
# Out:
# 20

# %%
my_artists_tracks[0]['tracks']['items'][49]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5V0MlUE1Bft0mbLlND7FJz'},
#     'href': 'https://api.spotify.com/v1/artists/5V0MlUE1Bft0mbLlND7FJz',
#     'id': '5V0MlUE1Bft0mbLlND7FJz',
#     'name': 'Ella Fitzgerald',
#     'type': 'artist',
#     'uri': 'spotify:artist:5V0MlUE1Bft0mbLlND7FJz'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4HfTyzIioLsV8YpFvY7Iga'},
#   'href': 'https://api.spotify.com/v1/albums/4HfTyzIioLsV8YpFvY7Iga',
#   'id': '4HfTyzIioLsV8YpFvY7Iga',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27321899f56f7942085625eb6ba',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0221899f56f7942085625eb6ba',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485121899f56f7942085625eb6ba',
#     'width': 64}],
#   'name': 'The Complete Decca Singles Vol. 2: 1939-1941',
#   'release_date': '2017-04-14',
#   'release_date_precision': 'day',
#   'total_tracks': 50,
#   'type': 'album',
#   'uri': 'spotify:album:4HfTyzIioLsV8YpFvY7Iga'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/02UotVhmqPg91twSGAwSgR'},
#    'href': 'https://api.spotify.com/v1/artists/02UotVhmqPg91twSGAwSgR',
#    'id': '02UotVhmqPg91twSGAwSgR',
#    'name': 'Ella Fitzgerald and Her Famous Orchestra',
#    'type': 'artist',
#    'uri': 'spotify:artist:02UotVhmqPg91twSGAwSgR'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 2,
#  'duration_ms': 176030,
#  'explicit': False,
#  'external_ids': {'isrc': 'USMC14169785'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/7g2xOQm7ZmiJXuKyNVKFq5'},
#  'href': 'https://api.spotify.com/v1/tracks/7g2xOQm7ZmiJXuKyNVKFq5',
#  'id': '7g2xOQm7ZmiJXuKyNVKFq5',
#  'is_local': False,
#  'name': 'This Love Of Mine',
#  'popularity': 19,
#  'preview_url': None,
#  'track_number': 19,
#  'type': 'track',
#  'uri': 'spotify:track:7g2xOQm7ZmiJXuKyNVKFq5'}

# %%
def artist_to_track_dict(artist_list):
    return {artist:sp.search(q=artist,limit=50) for artist in artist_list}

# %%
len(artist_to_track_dict(my_20_artists))
# Out:
# 20

# %%
my_dict=artist_to_track_dict(my_20_artists)

# %%
my_dict.keys()
# Out:
# dict_keys(['Ella Fitzgerald', 'Etta James', 'Louis Armstrong', 'Cole Porter', 'Billie Holiday', 'Dinah Washington', 'Queen', 'Beardyman', 'Lea Dasandre', 'Gregory Porter', 'Errol Linton', 'Nubya Garcia', 'Roxette', 'Prince', 'Ellie Goulding', 'Tracy Chapman', 'Fleetwood Mac', 'Morcheeba', 'Status Quo', 'The Doors'])

# %%
my_dict['Ella Fitzgerald'].keys()
# Out:
# dict_keys(['tracks'])

# %%
my_dict['Ella Fitzgerald']['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
my_dict['Ella Fitzgerald']['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
my_dict['Ella Fitzgerald']['tracks']['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5V0MlUE1Bft0mbLlND7FJz'},
#   'href': 'https://api.spotify.com/v1/artists/5V0MlUE1Bft0mbLlND7FJz',
#   'id': '5V0MlUE1Bft0mbLlND7FJz',
#   'name': 'Ella Fitzgerald',
#   'type': 'artist',
#   'uri': 'spotify:artist:5V0MlUE1Bft0mbLlND7FJz'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/19eLuQmk9aCobbVDHc6eek'},
#   'href': 'https://api.spotify.com/v1/artists/19eLuQmk9aCobbVDHc6eek',
#   'id': '19eLuQmk9aCobbVDHc6eek',
#   'name': 'Louis Armstrong',
#   'type': 'artist',
#   'uri': 'spotify:artist:19eLuQmk9aCobbVDHc6eek'}]

# %%
my_dict['Ella Fitzgerald']['tracks']['items'][0]['name']
# Out:
# 'Dream A Little Dream Of Me - Single Version'

# %%
my_dict['Ella Fitzgerald']['tracks']['items'][0]['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/track/78MI7mu1LV1k4IA2HzKmHe'}

# %%
my_dict['Ella Fitzgerald']['tracks']['items'][0]['uri']
# Out:
# 'spotify:track:78MI7mu1LV1k4IA2HzKmHe'

# %%
#experiment : 
three_artists = ["Dire Straits", "Queen", "Ella Fitzgerald"]

# %%
len(artist_to_track_dict(three_artists))
# Out:
# 3

# %% [markdown]
# ## take a look at artists and albums

# %%
results['tracks']['items'][13].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][13]['artists'][0]['name']
# Out:
# '2Pac'

# %%
results['tracks']['items'][13]['album'].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
results['tracks']['items'][13]['album']['name']
# Out:
# 'The Best Of 2Pac (Pt. 1: Thug)'

# %%
results['tracks']['items'][13]['album']['artists'][0]['name']
# Out:
# '2Pac'

# %% [markdown]
# ### 8.05 Activity 2
# - Create a function to extract all the artists of a song and another function to extract all the artists IDs from a song.
#
# - Input: track dictionary
# - Output: List of artists/List of IDs

# %%
results = sp.track('78MI7mu1LV1k4IA2HzKmHe', market='GB')

# %%
results.keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
type(results)
# Out:
# dict

# %%
range(len(results['artists']))
# Out:
# range(0, 2)

# %%
results['artists'][0]['id']
# Out:
# '5V0MlUE1Bft0mbLlND7FJz'

# %%
results['artists'][0]['name']
# Out:
# 'Ella Fitzgerald'

# %%
import pandas as pd

# %%
artist_names=[]
artist_ids=[]
def get_artist_from_track(track_id):
    search

# %%
song1artists = []
for artist in song1artists:
    song1artists.append(sp.search(q={artist}, limit=50))

# %%
song1artists
# Out:
# []

# %% [markdown]
# Explore the object returned by the request:

# %% [markdown]
# ## 2 password protection section

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri" or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.
#
# We'll use the `uri` in this code-along, but feel free to use whatever you think fits best your needs.

# %% [markdown]
# #### Searching multiple artists
#
# create a list of artists eg
#
# artists = ["Dire Straits", "Queen", "Ella Fitzgerald"]

# %% [markdown]
# #### Exploring the tracks

# %% [markdown]
# Function to get the artists involved in a song:

# %% [markdown]
# Function to get the "id's" of the artists from a song:

# %% [markdown]
# ### Playlists
#
# We will need to collect a "database" of songs. Playlists are a good way to access relatively large amounts of songs.

# %%
playlist = sp.user_playlist_tracks("yoda_bcn", "6u3Uqr1Mqj4JLsSRu2PSIh")

# %%
playlist_2 = sp.user_playlist_tracks("spotify", "37i9dQZF1DX1g0iEXLFycr")

# %%
playlist_2["total"]
# Out:
# 100

# %%
playlist_2['items'][0]['track']['id']
# Out:
# '6kopmMZiyLmw7h66uXcXR7'

# %%
import pandas as pd
import csv

# %%
PLAYLIST_LINK = "https://open.spotify.com/playlist/6u3Uqr1Mqj4JLsSRu2PSIh"

get_tracks=[]

def get_playlist_uri(playlist_link):
    return playlist_link.split("/")[-1].split("?")[0]


def get_tracks():
    tracks = []
    playlist_uri = get_playlist_uri(PLAYLIST_LINK)
    for track in sp.playlist_tracks(playlist_uri)["items"]:
        track_uri = track["track"]["uri"]
        track_name = track["track"]["name"]
        result = track_name, sp.audio_features(track_uri)
        tracks.append(result)

    return tracks

# %%
get_tracks()
# Out:
# [('Just The Way',
#   [{'danceability': 0.779,
#     'energy': 0.477,
#     'key': 8,
#     'loudness': -8.751,
#     'mode': 0,
#     'speechiness': 0.115,
#     'acousticness': 0.0635,
#     'instrumentalness': 0,
#     'liveness': 0.157,
#     'valence': 0.546,
#     'tempo': 88.987,
#     'type': 'audio_features',
#     'id': '4eMGevfobDTaWfr3TLbkFm',
#     'uri': 'spotify:track:4eMGevfobDTaWfr3TLbkFm',
#     'track_href': 'https://api.spotify.com/v1/tracks/4eMGevfobDTaWfr3TLbkFm',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eMGevfobDTaWfr3TLbkFm',
#     'duration_ms': 235907,
#     'time_signature': 4}]),
#  ('No Diggity',
#   [{'danceability': 0.867,
#     'energy': 0.646,
#     'key': 1,
#     'loudness': -4.674,
#     'mode': 0,
#     'speechiness': 0.288,
#     'acousticness': 0.303,
#     'instrumentalness': 0,
#     'liveness': 0.279,
#     'valence': 0.67,
#     'tempo': 88.634,
#     'type': 'audio_features',
#     'id': '6MdqqkQ8sSC0WB4i8PyRuQ',
#     'uri': 'spotify:track:6MdqqkQ8sSC0WB4i8PyRuQ',
#     'track_href': 'https://api.spotify.com/v1/tracks/6MdqqkQ8sSC0WB4i8PyRuQ',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6MdqqkQ8sSC0WB4i8PyRuQ',
#     'duration_ms': 304600,
#     'time_signature': 4}]),
#  ('One For The Money',
#   [{'danceability': 0.757,
#     'energy': 0.538,
#     'key': 3,
#     'loudness': -8.592,
#     'mode': 1,
#     'speechiness': 0.0434,
#     'acousticness': 0.0494,
#     'instrumentalness': 0,
#     'liveness': 0.0361,
#     'valence': 0.84,
#     'tempo': 90.065,
#     'type': 'audio_features',
#     'id': '4Ar06Zd03CZI7MKQDyNA7i',
#     'uri': 'spotify:track:4Ar06Zd03CZI7MKQDyNA7i',
#     'track_href': 'https://api.spotify.com/v1/tracks/4Ar06Zd03CZI7MKQDyNA7i',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Ar06Zd03CZI7MKQDyNA7i',
#     'duration_ms': 265467,
#     'time_signature': 4}]),
#  ("Got 'Til It's Gone",
#   [{'danceability': 0.789,
#     'energy': 0.412,
#     'key': 7,
#     'loudness': -7.518,
#     'mode': 1,
#     'speechiness': 0.243,
#     'acousticness': 0.0218,
#     'instrumentalness': 0.000312,
#     'liveness': 0.3,
#     'valence': 0.518,
#     'tempo': 89.914,
#     'type': 'audio_features',
#     'id': '6jUyYHDikmw9WltPojSR37',
#     'uri': 'spotify:track:6jUyYHDikmw9WltPojSR37',
#     'track_href': 'https://api.spotify.com/v1/tracks/6jUyYHDikmw9WltPojSR37',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6jUyYHDikmw9WltPojSR37',
#     'duration_ms': 241760,
#     'time_signature': 4}]),
#  ('Jerk (feat. 50 Cent) - Club Mix',
#   [{'danceability': 0.861,
#     'energy': 0.592,
#     'key': 2,
#     'loudness': -7.083,
#     'mode': 1,
#     'speechiness': 0.403,
#     'acousticness': 0.0227,
#     'instrumentalness': 1.37e-06,
#     'liveness': 0.0237,
#     'valence': 0.903,
#     'tempo': 90.018,
#     'type': 'audio_features',
#     'id': '54mEyOL9DbvNdVz6kX3aJj',
#     'uri': 'spotify:track:54mEyOL9DbvNdVz6kX3aJj',
#     'track_href': 'https://api.spotify.com/v1/tracks/54mEyOL9DbvNdVz6kX3aJj',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/54mEyOL9DbvNdVz6kX3aJj',
#     'duration_ms': 225533,
#     'time_signature': 4}]),
#  ('Whatta Man',
#   [{'danceability': 0.757,
#     'energy': 0.544,
#     'key': 5,
#     'loudness': -10.722,
#     'mode': 1,
#     'speechiness': 0.219,
#     'acousticness': 0.154,
#     'instrumentalness': 6.07e-05,
#     'liveness': 0.226,
#     'valence': 0.921,
#     'tempo': 173.208,
#     'type': 'audio_features',
#     'id': '7sJN693sYKEIEMu7fc5VnJ',
#     'uri': 'spotify:track:7sJN693sYKEIEMu7fc5VnJ',
#     'track_href': 'https://api.spotify.com/v1/tracks/7sJN693sYKEIEMu7fc5VnJ',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sJN693sYKEIEMu7fc5VnJ',
#     'duration_ms': 308360,
#     'time_signature': 4}]),
#  ('Steelo',
#   [{'danceability': 0.767,
#     'energy': 0.73,
#     'key': 8,
#     'loudness': -8.109,
#     'mode': 0,
#     'speechiness': 0.112,
#     'acousticness': 0.102,
#     'instrumentalness': 0.0039,
#     'liveness': 0.102,
#     'valence': 0.683,
#     'tempo': 90.997,
#     'type': 'audio_features',
#     'id': '6p1k1aQbvWp0QZfTQm2p6g',
#     'uri': 'spotify:track:6p1k1aQbvWp0QZfTQm2p6g',
#     'track_href': 'https://api.spotify.com/v1/tracks/6p1k1aQbvWp0QZfTQm2p6g',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6p1k1aQbvWp0QZfTQm2p6g',
#     'duration_ms': 257960,
#     'time_signature': 4}]),
#  ('Freak Like Me',
#   [{'danceability': 0.655,
#     'energy': 0.837,
#     'key': 11,
#     'loudness': -6.04,
#     'mode': 0,
#     'speechiness': 0.0723,
#     'acousticness': 0.0262,
#     'instrumentalness': 5.85e-06,
#     'liveness': 0.0454,
#     'valence': 0.66,
#     'tempo': 91.014,
#     'type': 'audio_features',
#     'id': '6Vas6h9lB5mmeVDXdFqlQA',
#     'uri': 'spotify:track:6Vas6h9lB5mmeVDXdFqlQA',
#     'track_href': 'https://api.spotify.com/v1/tracks/6Vas6h9lB5mmeVDXdFqlQA',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Vas6h9lB5mmeVDXdFqlQA',
#     'duration_ms': 253613,
#     'time_signature': 4}]),
#  ('No, No, No Pt. 2 (feat. Wyclef Jean)',
#   [{'danceability': 0.676,
#     'energy': 0.575,
#     'key': 1,
#     'loudness': -3.603,
#     'mode': 1,
#     'speechiness': 0.27,
#     'acousticness': 0.318,
#     'instrumentalness': 0,
#     'liveness': 0.101,
#     'valence': 0.67,
#     'tempo': 181.898,
#     'type': 'audio_features',
#     'id': '532ZaZeuPXlXLAR4xZcxQi',
#     'uri': 'spotify:track:532ZaZeuPXlXLAR4xZcxQi',
#     'track_href': 'https://api.spotify.com/v1/tracks/532ZaZeuPXlXLAR4xZcxQi',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/532ZaZeuPXlXLAR4xZcxQi',
#     'duration_ms': 207733,
#     'time_signature': 4}]),
#  ('I Love You - Remix',
#   [{'danceability': 0.771,
#     'energy': 0.672,
#     'key': 11,
#     'loudness': -9.281,
#     'mode': 0,
#     'speechiness': 0.0527,
#     'acousticness': 0.33,
#     'instrumentalness': 0.000208,
#     'liveness': 0.156,
#     'valence': 0.753,
#     'tempo': 91.048,
#     'type': 'audio_features',
#     'id': '77LGPtl2gLLn711D31udwb',
#     'uri': 'spotify:track:77LGPtl2gLLn711D31udwb',
#     'track_href': 'https://api.spotify.com/v1/tracks/77LGPtl2gLLn711D31udwb',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77LGPtl2gLLn711D31udwb',
#     'duration_ms': 295893,
#     'time_signature': 4}]),
#  ('People Everyday - Metamorphosis Mix',
#   [{'danceability': 0.843,
#     'energy': 0.508,
#     'key': 10,
#     'loudness': -13.918,
#     'mode': 1,
#     'speechiness': 0.221,
#     'acousticness': 0.00852,
#     'instrumentalness': 2.1e-06,
#     'liveness': 0.648,
#     'valence': 0.704,
#     'tempo': 91.094,
#     'type': 'audio_features',
#     'id': '1nSUJWYRqsafI8Bh1X0ypp',
#     'uri': 'spotify:track:1nSUJWYRqsafI8Bh1X0ypp',
#     'track_href': 'https://api.spotify.com/v1/tracks/1nSUJWYRqsafI8Bh1X0ypp',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1nSUJWYRqsafI8Bh1X0ypp',
#     'duration_ms': 298773,
#     'time_signature': 4}]),
#  ('Head Over Heels (feat. Nas)',
#   [{'danceability': 0.83,
#     'energy': 0.638,
#     'key': 10,
#     'loudness': -7.023,
#     'mode': 0,
#     'speechiness': 0.142,
#     'acousticness': 0.0774,
#     'instrumentalness': 1.71e-06,
#     'liveness': 0.392,
#     'valence': 0.738,
#     'tempo': 96.075,
#     'type': 'audio_features',
#     'id': '4QVqhtRbJP1hVqWAU6XZbw',
#     'uri': 'spotify:track:4QVqhtRbJP1hVqWAU6XZbw',
#     'track_href': 'https://api.spotify.com/v1/tracks/4QVqhtRbJP1hVqWAU6XZbw',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4QVqhtRbJP1hVqWAU6XZbw',
#     'duration_ms': 250973,
#     'time_signature': 4}]),
#  ('Top of the World (feat. Mase)',
#   [{'danceability': 0.839,
#     'energy': 0.621,
#     'key': 1,
#     'loudness': -5.739,
#     'mode': 1,
#     'speechiness': 0.132,
#     'acousticness': 0.00301,
#     'instrumentalness': 0.0314,
#     'liveness': 0.105,
#     'valence': 0.855,
#     'tempo': 98.015,
#     'type': 'audio_features',
#     'id': '6BxiFSFVzviEqe2eIaruLV',
#     'uri': 'spotify:track:6BxiFSFVzviEqe2eIaruLV',
#     'track_href': 'https://api.spotify.com/v1/tracks/6BxiFSFVzviEqe2eIaruLV',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6BxiFSFVzviEqe2eIaruLV',
#     'duration_ms': 281507,
#     'time_signature': 4}]),
#  ('Stand Up (Featuring Ghostface Killah) (feat. Ghostface Killah)',
#   [{'danceability': 0.831,
#     'energy': 0.635,
#     'key': 9,
#     'loudness': -10.896,
#     'mode': 1,
#     'speechiness': 0.281,
#     'acousticness': 0.285,
#     'instrumentalness': 0,
#     'liveness': 0.142,
#     'valence': 0.799,
#     'tempo': 98.116,
#     'type': 'audio_features',
#     'id': '1OthLEsS1Qc4zwEjJ2E2Xx',
#     'uri': 'spotify:track:1OthLEsS1Qc4zwEjJ2E2Xx',
#     'track_href': 'https://api.spotify.com/v1/tracks/1OthLEsS1Qc4zwEjJ2E2Xx',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1OthLEsS1Qc4zwEjJ2E2Xx',
#     'duration_ms': 284867,
#     'time_signature': 4}]),
#  ("That's The Way Love Goes",
#   [{'danceability': 0.703,
#     'energy': 0.7,
#     'key': 5,
#     'loudness': -6.789,
#     'mode': 1,
#     'speechiness': 0.0693,
#     'acousticness': 0.302,
#     'instrumentalness': 0.471,
#     'liveness': 0.0718,
#     'valence': 0.582,
#     'tempo': 97.675,
#     'type': 'audio_features',
#     'id': '29rQJydAlO0uMyWvRIZxQg',
#     'uri': 'spotify:track:29rQJydAlO0uMyWvRIZxQg',
#     'track_href': 'https://api.spotify.com/v1/tracks/29rQJydAlO0uMyWvRIZxQg',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/29rQJydAlO0uMyWvRIZxQg',
#     'duration_ms': 265107,
#     'time_signature': 4}]),
#  ('Forgive Them Father',
#   [{'danceability': 0.808,
#     'energy': 0.6,
#     'key': 4,
#     'loudness': -7.41,
#     'mode': 0,
#     'speechiness': 0.142,
#     'acousticness': 0.049,
#     'instrumentalness': 2.36e-05,
#     'liveness': 0.139,
#     'valence': 0.691,
#     'tempo': 97.939,
#     'type': 'audio_features',
#     'id': '35zq0is9h4tI8N8FPNsUtn',
#     'uri': 'spotify:track:35zq0is9h4tI8N8FPNsUtn',
#     'track_href': 'https://api.spotify.com/v1/tracks/35zq0is9h4tI8N8FPNsUtn',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/35zq0is9h4tI8N8FPNsUtn',
#     'duration_ms': 315293,
#     'time_signature': 4}]),
#  ('Real Love Remix (feat. The Notorious B.I.G.)',
#   [{'danceability': 0.796,
#     'energy': 0.809,
#     'key': 1,
#     'loudness': -6.352,
#     'mode': 1,
#     'speechiness': 0.243,
#     'acousticness': 0.00338,
#     'instrumentalness': 0.0569,
#     'liveness': 0.186,
#     'valence': 0.506,
#     'tempo': 97.896,
#     'type': 'audio_features',
#     'id': '3z0HBYkS1Nnt3ORqIU1vjr',
#     'uri': 'spotify:track:3z0HBYkS1Nnt3ORqIU1vjr',
#     'track_href': 'https://api.spotify.com/v1/tracks/3z0HBYkS1Nnt3ORqIU1vjr',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3z0HBYkS1Nnt3ORqIU1vjr',
#     'duration_ms': 279240,
#     'time_signature': 4}]),
#  ('Maria Maria (feat. The Product G&B)',
#   [{'danceability': 0.777,
#     'energy': 0.601,
#     'key': 2,
#     'loudness': -5.931,
#     'mode': 1,
#     'speechiness': 0.126,
#     'acousticness': 0.0406,
#     'instrumentalness': 0.00201,
#     'liveness': 0.0348,
#     'valence': 0.68,
#     'tempo': 97.911,
#     'type': 'audio_features',
#     'id': '3XKIUb7HzIF1Vu9usunMzc',
#     'uri': 'spotify:track:3XKIUb7HzIF1Vu9usunMzc',
#     'track_href': 'https://api.spotify.com/v1/tracks/3XKIUb7HzIF1Vu9usunMzc',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3XKIUb7HzIF1Vu9usunMzc',
#     'duration_ms': 261973,
#     'time_signature': 4}]),
#  ("You're The One I Love",
#   [{'danceability': 0.761,
#     'energy': 0.825,
#     'key': 10,
#     'loudness': -2.983,
#     'mode': 0,
#     'speechiness': 0.0479,
#     'acousticness': 0.0341,
#     'instrumentalness': 1.39e-05,
#     'liveness': 0.0583,
#     'valence': 0.86,
#     'tempo': 97.571,
#     'type': 'audio_features',
#     'id': '2O0x4v0CKubvy9bYj9BKwq',
#     'uri': 'spotify:track:2O0x4v0CKubvy9bYj9BKwq',
#     'track_href': 'https://api.spotify.com/v1/tracks/2O0x4v0CKubvy9bYj9BKwq',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2O0x4v0CKubvy9bYj9BKwq',
#     'duration_ms': 253547,
#     'time_signature': 4}]),
#  ('Da B Side (feat. The Notorious B.I.G.)',
#   [{'danceability': 0.849,
#     'energy': 0.61,
#     'key': 8,
#     'loudness': -10.822,
#     'mode': 1,
#     'speechiness': 0.154,
#     'acousticness': 0.0204,
#     'instrumentalness': 4.76e-06,
#     'liveness': 0.0454,
#     'valence': 0.566,
#     'tempo': 99.01,
#     'type': 'audio_features',
#     'id': '3VXdEVTbT6SLTrOLEX7MCr',
#     'uri': 'spotify:track:3VXdEVTbT6SLTrOLEX7MCr',
#     'track_href': 'https://api.spotify.com/v1/tracks/3VXdEVTbT6SLTrOLEX7MCr',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3VXdEVTbT6SLTrOLEX7MCr',
#     'duration_ms': 223693,
#     'time_signature': 4}]),
#  ('Sweetheart (feat. Mariah Carey)',
#   [{'danceability': 0.773,
#     'energy': 0.499,
#     'key': 11,
#     'loudness': -8.361,
#     'mode': 0,
#     'speechiness': 0.05,
#     'acousticness': 0.0717,
#     'instrumentalness': 1.89e-06,
#     'liveness': 0.109,
#     'valence': 0.629,
#     'tempo': 99.119,
#     'type': 'audio_features',
#     'id': '4LU9Gg0njNhCS2QbUS4xut',
#     'uri': 'spotify:track:4LU9Gg0njNhCS2QbUS4xut',
#     'track_href': 'https://api.spotify.com/v1/tracks/4LU9Gg0njNhCS2QbUS4xut',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4LU9Gg0njNhCS2QbUS4xut',
#     'duration_ms': 260267,
#     'time_signature': 4}]),
#  ('Every Little Thing I Do - Remix',
#   [{'danceability': 0.811,
#     'energy': 0.524,
#     'key': 7,
#     'loudness': -7.81,
#     'mode': 0,
#     'speechiness': 0.0539,
#     'acousticness': 0.464,
#     'instrumentalness': 2.05e-06,
#     'liveness': 0.0635,
#     'valence': 0.778,
#     'tempo': 98.929,
#     'type': 'audio_features',
#     'id': '6XgHh91UD5IMETc9IEiawG',
#     'uri': 'spotify:track:6XgHh91UD5IMETc9IEiawG',
#     'track_href': 'https://api.spotify.com/v1/tracks/6XgHh91UD5IMETc9IEiawG',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6XgHh91UD5IMETc9IEiawG',
#     'duration_ms': 303494,
#     'time_signature': 4}]),
#  ("Gone Till November (feat. R. Kelly & Canibus) - The Makin' Runs Remix",
#   [{'danceability': 0.809,
#     'energy': 0.518,
#     'key': 11,
#     'loudness': -8.344,
#     'mode': 0,
#     'speechiness': 0.281,
#     'acousticness': 0.0726,
#     'instrumentalness': 0,
#     'liveness': 0.126,
#     'valence': 0.806,
#     'tempo': 98.027,
#     'type': 'audio_features',
#     'id': '5Y0owZ8NszGudca8OAXQHu',
#     'uri': 'spotify:track:5Y0owZ8NszGudca8OAXQHu',
#     'track_href': 'https://api.spotify.com/v1/tracks/5Y0owZ8NszGudca8OAXQHu',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Y0owZ8NszGudca8OAXQHu',
#     'duration_ms': 221933,
#     'time_signature': 4}]),
#  ('Every Little Step',
#   [{'danceability': 0.781,
#     'energy': 0.638,
#     'key': 1,
#     'loudness': -12.305,
#     'mode': 1,
#     'speechiness': 0.0401,
#     'acousticness': 0.00911,
#     'instrumentalness': 0,
#     'liveness': 0.0357,
#     'valence': 0.909,
#     'tempo': 100.231,
#     'type': 'audio_features',
#     'id': '3PAYDLeC1RxDIbzi9hZYne',
#     'uri': 'spotify:track:3PAYDLeC1RxDIbzi9hZYne',
#     'track_href': 'https://api.spotify.com/v1/tracks/3PAYDLeC1RxDIbzi9hZYne',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3PAYDLeC1RxDIbzi9hZYne',
#     'duration_ms': 236240,
#     'time_signature': 4}]),
#  ('All Night Long (feat. P. Diddy)',
#   [{'danceability': 0.713,
#     'energy': 0.779,
#     'key': 11,
#     'loudness': -4.726,
#     'mode': 0,
#     'speechiness': 0.238,
#     'acousticness': 0.00946,
#     'instrumentalness': 0,
#     'liveness': 0.0805,
#     'valence': 0.725,
#     'tempo': 100.404,
#     'type': 'audio_features',
#     'id': '1C7ebyOVDboehxsJmk5w4e',
#     'uri': 'spotify:track:1C7ebyOVDboehxsJmk5w4e',
#     'track_href': 'https://api.spotify.com/v1/tracks/1C7ebyOVDboehxsJmk5w4e',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1C7ebyOVDboehxsJmk5w4e',
#     'duration_ms': 259307,
#     'time_signature': 4}]),
#  ('Shake It Up',
#   [{'danceability': 0.819,
#     'energy': 0.849,
#     'key': 5,
#     'loudness': -4.17,
#     'mode': 1,
#     'speechiness': 0.0868,
#     'acousticness': 0.103,
#     'instrumentalness': 0,
#     'liveness': 0.212,
#     'valence': 0.749,
#     'tempo': 101.089,
#     'type': 'audio_features',
#     'id': '6hIfT7IA37KrXAUz40QkRc',
#     'uri': 'spotify:track:6hIfT7IA37KrXAUz40QkRc',
#     'track_href': 'https://api.spotify.com/v1/tracks/6hIfT7IA37KrXAUz40QkRc',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6hIfT7IA37KrXAUz40QkRc',
#     'duration_ms': 290160,
#     'time_signature': 4}]),
#  ('Doo Wop (That Thing)',
#   [{'danceability': 0.535,
#     'energy': 0.505,
#     'key': 2,
#     'loudness': -8.926,
#     'mode': 0,
#     'speechiness': 0.245,
#     'acousticness': 0.0393,
#     'instrumentalness': 0,
#     'liveness': 0.0923,
#     'valence': 0.495,
#     'tempo': 99.935,
#     'type': 'audio_features',
#     'id': '2Uu8IiLkLY0UXhCHka4Dlr',
#     'uri': 'spotify:track:2Uu8IiLkLY0UXhCHka4Dlr',
#     'track_href': 'https://api.spotify.com/v1/tracks/2Uu8IiLkLY0UXhCHka4Dlr',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Uu8IiLkLY0UXhCHka4Dlr',
#     'duration_ms': 320267,
#     'time_signature': 4}]),
#  ('Wifey - Club Mix/Dirty Version',
#   [{'danceability': 0.831,
#     'energy': 0.713,
#     'key': 7,
#     'loudness': -6.967,
#     'mode': 0,
#     'speechiness': 0.104,
#     'acousticness': 0.0678,
#     'instrumentalness': 0,
#     'liveness': 0.0659,
#     'valence': 0.683,
#     'tempo': 99.584,
#     'type': 'audio_features',
#     'id': '1NNDZc9BHaWe9JqIsPRlNV',
#     'uri': 'spotify:track:1NNDZc9BHaWe9JqIsPRlNV',
#     'track_href': 'https://api.spotify.com/v1/tracks/1NNDZc9BHaWe9JqIsPRlNV',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1NNDZc9BHaWe9JqIsPRlNV',
#     'duration_ms': 243467,
#     'time_signature': 4}]),
#  ('Home Alone (feat. Keith Murray)',
#   [{'danceability': 0.887,
#     'energy': 0.643,
#     'key': 4,
#     'loudness': -2.578,
#     'mode': 0,
#     'speechiness': 0.214,
#     'acousticness': 0.0447,
#     'instrumentalness': 0,
#     'liveness': 0.132,
#     'valence': 0.513,
#     'tempo': 99.533,
#     'type': 'audio_features',
#     'id': '4UDQEazTqhCICqssWtMZEO',
#     'uri': 'spotify:track:4UDQEazTqhCICqssWtMZEO',
#     'track_href': 'https://api.spotify.com/v1/tracks/4UDQEazTqhCICqssWtMZEO',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4UDQEazTqhCICqssWtMZEO',
#     'duration_ms': 299560,
#     'time_signature': 4}]),
#  ('So You Like What You See',
#   [{'danceability': 0.679,
#     'energy': 0.859,
#     'key': 0,
#     'loudness': -7.88,
#     'mode': 1,
#     'speechiness': 0.0686,
#     'acousticness': 0.387,
#     'instrumentalness': 0,
#     'liveness': 0.097,
#     'valence': 0.893,
#     'tempo': 99.845,
#     'type': 'audio_features',
#     'id': '6rVDypmrk2ub86XUF402uU',
#     'uri': 'spotify:track:6rVDypmrk2ub86XUF402uU',
#     'track_href': 'https://api.spotify.com/v1/tracks/6rVDypmrk2ub86XUF402uU',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6rVDypmrk2ub86XUF402uU',
#     'duration_ms': 281320,
#     'time_signature': 4}]),
#  ('Love Like This',
#   [{'danceability': 0.767,
#     'energy': 0.551,
#     'key': 0,
#     'loudness': -7.328,
#     'mode': 1,
#     'speechiness': 0.0616,
#     'acousticness': 0.00364,
#     'instrumentalness': 0,
#     'liveness': 0.0451,
#     'valence': 0.796,
#     'tempo': 100.904,
#     'type': 'audio_features',
#     'id': '7MQywXGHEev7JmwwIzMcao',
#     'uri': 'spotify:track:7MQywXGHEev7JmwwIzMcao',
#     'track_href': 'https://api.spotify.com/v1/tracks/7MQywXGHEev7JmwwIzMcao',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MQywXGHEev7JmwwIzMcao',
#     'duration_ms': 275707,
#     'time_signature': 4}]),
#  ("Nuttin' But Love",
#   [{'danceability': 0.731,
#     'energy': 0.499,
#     'key': 11,
#     'loudness': -13.619,
#     'mode': 0,
#     'speechiness': 0.374,
#     'acousticness': 0.0527,
#     'instrumentalness': 0.0015,
#     'liveness': 0.0362,
#     'valence': 0.47,
#     'tempo': 202.675,
#     'type': 'audio_features',
#     'id': '43JSZNyRzLa3nD9W0hfD48',
#     'uri': 'spotify:track:43JSZNyRzLa3nD9W0hfD48',
#     'track_href': 'https://api.spotify.com/v1/tracks/43JSZNyRzLa3nD9W0hfD48',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43JSZNyRzLa3nD9W0hfD48',
#     'duration_ms': 213733,
#     'time_signature': 4}]),
#  ('Throw Your Hands Up - Treach Version',
#   [{'danceability': 0.849,
#     'energy': 0.727,
#     'key': 9,
#     'loudness': -4.572,
#     'mode': 0,
#     'speechiness': 0.0534,
#     'acousticness': 0.148,
#     'instrumentalness': 2.17e-05,
#     'liveness': 0.0453,
#     'valence': 0.7,
#     'tempo': 100.927,
#     'type': 'audio_features',
#     'id': '5AQXqGCGr4AIKsWDMv18YB',
#     'uri': 'spotify:track:5AQXqGCGr4AIKsWDMv18YB',
#     'track_href': 'https://api.spotify.com/v1/tracks/5AQXqGCGr4AIKsWDMv18YB',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5AQXqGCGr4AIKsWDMv18YB',
#     'duration_ms': 230227,
#     'time_signature': 4}]),
#  ('Get A Life',
#   [{'danceability': 0.761,
#     'energy': 0.715,
#     'key': 10,
#     'loudness': -11.699,
#     'mode': 0,
#     'speechiness': 0.0669,
#     'acousticness': 0.00321,
#     'instrumentalness': 0.0989,
#     'liveness': 0.0484,
#     'valence': 0.715,
#     'tempo': 101.132,
#     'type': 'audio_features',
#     'id': '5HRaxiZNh5CDACzSSYleHx',
#     'uri': 'spotify:track:5HRaxiZNh5CDACzSSYleHx',
#     'track_href': 'https://api.spotify.com/v1/tracks/5HRaxiZNh5CDACzSSYleHx',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5HRaxiZNh5CDACzSSYleHx',
#     'duration_ms': 224173,
#     'time_signature': 4}]),
#  ('Hey Mr. D.J.',
#   [{'danceability': 0.865,
#     'energy': 0.557,
#     'key': 2,
#     'loudness': -8.018,
#     'mode': 1,
#     'speechiness': 0.0612,
#     'acousticness': 0.0221,
#     'instrumentalness': 0.00353,
#     'liveness': 0.0973,
#     'valence': 0.859,
#     'tempo': 101.295,
#     'type': 'audio_features',
#     'id': '6eB35pgMXdfhz5Z0WjwF1O',
#     'uri': 'spotify:track:6eB35pgMXdfhz5Z0WjwF1O',
#     'track_href': 'https://api.spotify.com/v1/tracks/6eB35pgMXdfhz5Z0WjwF1O',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6eB35pgMXdfhz5Z0WjwF1O',
#     'duration_ms': 252400,
#     'time_signature': 4}]),
#  ('Respect (feat. Vinia Mojica)',
#   [{'danceability': 0.855,
#     'energy': 0.47,
#     'key': 5,
#     'loudness': -10.11,
#     'mode': 1,
#     'speechiness': 0.165,
#     'acousticness': 0.341,
#     'instrumentalness': 2.33e-05,
#     'liveness': 0.113,
#     'valence': 0.761,
#     'tempo': 102.187,
#     'type': 'audio_features',
#     'id': '3mgFUpTSGwwyZL11YTu8cw',
#     'uri': 'spotify:track:3mgFUpTSGwwyZL11YTu8cw',
#     'track_href': 'https://api.spotify.com/v1/tracks/3mgFUpTSGwwyZL11YTu8cw',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3mgFUpTSGwwyZL11YTu8cw',
#     'duration_ms': 274533,
#     'time_signature': 4}]),
#  ('On Our Own',
#   [{'danceability': 0.692,
#     'energy': 0.797,
#     'key': 2,
#     'loudness': -7.146,
#     'mode': 1,
#     'speechiness': 0.0554,
#     'acousticness': 0.00436,
#     'instrumentalness': 0,
#     'liveness': 0.0437,
#     'valence': 0.552,
#     'tempo': 102.672,
#     'type': 'audio_features',
#     'id': '10YJZFvi3ewpy1nICSAPUT',
#     'uri': 'spotify:track:10YJZFvi3ewpy1nICSAPUT',
#     'track_href': 'https://api.spotify.com/v1/tracks/10YJZFvi3ewpy1nICSAPUT',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10YJZFvi3ewpy1nICSAPUT',
#     'duration_ms': 269000,
#     'time_signature': 4}]),
#  ('Whatever - Radio Edit',
#   [{'danceability': 0.824,
#     'energy': 0.708,
#     'key': 10,
#     'loudness': -6.037,
#     'mode': 0,
#     'speechiness': 0.0712,
#     'acousticness': 0.00223,
#     'instrumentalness': 0,
#     'liveness': 0.0902,
#     'valence': 0.767,
#     'tempo': 101.854,
#     'type': 'audio_features',
#     'id': '3tHAB8FI4rfULUHHG1d2Ct',
#     'uri': 'spotify:track:3tHAB8FI4rfULUHHG1d2Ct',
#     'track_href': 'https://api.spotify.com/v1/tracks/3tHAB8FI4rfULUHHG1d2Ct',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3tHAB8FI4rfULUHHG1d2Ct',
#     'duration_ms': 228159,
#     'time_signature': 4}]),
#  ('Fantasy (feat. O.D.B.)',
#   [{'danceability': 0.837,
#     'energy': 0.548,
#     'key': 2,
#     'loudness': -9.658,
#     'mode': 1,
#     'speechiness': 0.116,
#     'acousticness': 0.0407,
#     'instrumentalness': 0,
#     'liveness': 0.05,
#     'valence': 0.821,
#     'tempo': 102.497,
#     'type': 'audio_features',
#     'id': '2itAOPLerxnnc8KXHMqPWu',
#     'uri': 'spotify:track:2itAOPLerxnnc8KXHMqPWu',
#     'track_href': 'https://api.spotify.com/v1/tracks/2itAOPLerxnnc8KXHMqPWu',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2itAOPLerxnnc8KXHMqPWu',
#     'duration_ms': 290467,
#     'time_signature': 4}]),
#  ('Jamaican in New York',
#   [{'danceability': 0.719,
#     'energy': 0.661,
#     'key': 11,
#     'loudness': -10.036,
#     'mode': 0,
#     'speechiness': 0.0528,
#     'acousticness': 0.00224,
#     'instrumentalness': 0.000189,
#     'liveness': 0.174,
#     'valence': 0.524,
#     'tempo': 101.723,
#     'type': 'audio_features',
#     'id': '2CL1Q0rQcbKavqqzu3zjQ2',
#     'uri': 'spotify:track:2CL1Q0rQcbKavqqzu3zjQ2',
#     'track_href': 'https://api.spotify.com/v1/tracks/2CL1Q0rQcbKavqqzu3zjQ2',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2CL1Q0rQcbKavqqzu3zjQ2',
#     'duration_ms': 268973,
#     'time_signature': 4}]),
#  ("Dancin'",
#   [{'danceability': 0.793,
#     'energy': 0.698,
#     'key': 10,
#     'loudness': -3.91,
#     'mode': 0,
#     'speechiness': 0.145,
#     'acousticness': 0.122,
#     'instrumentalness': 0,
#     'liveness': 0.0976,
#     'valence': 0.801,
#     'tempo': 101.01,
#     'type': 'audio_features',
#     'id': '6eTe69Nnhwi6DPn2PkPqp0',
#     'uri': 'spotify:track:6eTe69Nnhwi6DPn2PkPqp0',
#     'track_href': 'https://api.spotify.com/v1/tracks/6eTe69Nnhwi6DPn2PkPqp0',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6eTe69Nnhwi6DPn2PkPqp0',
#     'duration_ms': 249733,
#     'time_signature': 4}]),
#  ('This Is How We Do It',
#   [{'danceability': 0.791,
#     'energy': 0.702,
#     'key': 1,
#     'loudness': -7.333,
#     'mode': 1,
#     'speechiness': 0.0623,
#     'acousticness': 0.0174,
#     'instrumentalness': 0,
#     'liveness': 0.423,
#     'valence': 0.789,
#     'tempo': 103.646,
#     'type': 'audio_features',
#     'id': '6aJ90LBl96bly9zuEH1U2X',
#     'uri': 'spotify:track:6aJ90LBl96bly9zuEH1U2X',
#     'track_href': 'https://api.spotify.com/v1/tracks/6aJ90LBl96bly9zuEH1U2X',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6aJ90LBl96bly9zuEH1U2X',
#     'duration_ms': 237547,
#     'time_signature': 4}]),
#  ('U Know What\'s Up (feat. Lisa "Left Eye" Lopes)',
#   [{'danceability': 0.854,
#     'energy': 0.543,
#     'key': 8,
#     'loudness': -6.166,
#     'mode': 0,
#     'speechiness': 0.0844,
#     'acousticness': 0.0402,
#     'instrumentalness': 5.73e-05,
#     'liveness': 0.0419,
#     'valence': 0.868,
#     'tempo': 103.032,
#     'type': 'audio_features',
#     'id': '5PMKzsUsTpZZGsCcJBuhP2',
#     'uri': 'spotify:track:5PMKzsUsTpZZGsCcJBuhP2',
#     'track_href': 'https://api.spotify.com/v1/tracks/5PMKzsUsTpZZGsCcJBuhP2',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5PMKzsUsTpZZGsCcJBuhP2',
#     'duration_ms': 243733,
#     'time_signature': 4}]),
#  ('Bug a Boo (H-Town Screwed Mix)',
#   [{'danceability': 0.787,
#     'energy': 0.718,
#     'key': 6,
#     'loudness': -3.069,
#     'mode': 1,
#     'speechiness': 0.136,
#     'acousticness': 0.00501,
#     'instrumentalness': 1.81e-06,
#     'liveness': 0.204,
#     'valence': 0.906,
#     'tempo': 104.435,
#     'type': 'audio_features',
#     'id': '0Mbt4mulsW55ZfwMWXdOV1',
#     'uri': 'spotify:track:0Mbt4mulsW55ZfwMWXdOV1',
#     'track_href': 'https://api.spotify.com/v1/tracks/0Mbt4mulsW55ZfwMWXdOV1',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Mbt4mulsW55ZfwMWXdOV1',
#     'duration_ms': 212440,
#     'time_signature': 4}]),
#  ('Here We Go Again!',
#   [{'danceability': 0.788,
#     'energy': 0.778,
#     'key': 11,
#     'loudness': -9.825,
#     'mode': 0,
#     'speechiness': 0.0758,
#     'acousticness': 0.0112,
#     'instrumentalness': 0.024,
#     'liveness': 0.225,
#     'valence': 0.596,
#     'tempo': 106.273,
#     'type': 'audio_features',
#     'id': '6BDzQttUdcszjA8Fxqo1zQ',
#     'uri': 'spotify:track:6BDzQttUdcszjA8Fxqo1zQ',
#     'track_href': 'https://api.spotify.com/v1/tracks/6BDzQttUdcszjA8Fxqo1zQ',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6BDzQttUdcszjA8Fxqo1zQ',
#     'duration_ms': 260400,
#     'time_signature': 4}]),
#  ('What About Your Friends',
#   [{'danceability': 0.744,
#     'energy': 0.851,
#     'key': 10,
#     'loudness': -10.108,
#     'mode': 0,
#     'speechiness': 0.049,
#     'acousticness': 0.0267,
#     'instrumentalness': 0.00738,
#     'liveness': 0.0989,
#     'valence': 0.626,
#     'tempo': 105.882,
#     'type': 'audio_features',
#     'id': '63PIgPkDf3rswlU4ZWCYAM',
#     'uri': 'spotify:track:63PIgPkDf3rswlU4ZWCYAM',
#     'track_href': 'https://api.spotify.com/v1/tracks/63PIgPkDf3rswlU4ZWCYAM',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/63PIgPkDf3rswlU4ZWCYAM',
#     'duration_ms': 293600,
#     'time_signature': 4}]),
#  ('Big Bad Mama',
#   [{'danceability': 0.904,
#     'energy': 0.583,
#     'key': 10,
#     'loudness': -6.778,
#     'mode': 0,
#     'speechiness': 0.169,
#     'acousticness': 0.0031,
#     'instrumentalness': 0.000199,
#     'liveness': 0.076,
#     'valence': 0.648,
#     'tempo': 106.981,
#     'type': 'audio_features',
#     'id': '57YCM7W6GBs1FoGJfVC9wx',
#     'uri': 'spotify:track:57YCM7W6GBs1FoGJfVC9wx',
#     'track_href': 'https://api.spotify.com/v1/tracks/57YCM7W6GBs1FoGJfVC9wx',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57YCM7W6GBs1FoGJfVC9wx',
#     'duration_ms': 231920,
#     'time_signature': 4}]),
#  ("Let's Talk About Sex",
#   [{'danceability': 0.863,
#     'energy': 0.543,
#     'key': 6,
#     'loudness': -13.497,
#     'mode': 1,
#     'speechiness': 0.13,
#     'acousticness': 0.0507,
#     'instrumentalness': 0,
#     'liveness': 0.241,
#     'valence': 0.799,
#     'tempo': 106.929,
#     'type': 'audio_features',
#     'id': '6hTBP6QLwJdxbKyLlLXrGo',
#     'uri': 'spotify:track:6hTBP6QLwJdxbKyLlLXrGo',
#     'track_href': 'https://api.spotify.com/v1/tracks/6hTBP6QLwJdxbKyLlLXrGo',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6hTBP6QLwJdxbKyLlLXrGo',
#     'duration_ms': 213267,
#     'time_signature': 4}]),
#  ('Shame',
#   [{'danceability': 0.778,
#     'energy': 0.784,
#     'key': 11,
#     'loudness': -4.092,
#     'mode': 0,
#     'speechiness': 0.0384,
#     'acousticness': 0.126,
#     'instrumentalness': 0.0049,
#     'liveness': 0.168,
#     'valence': 0.893,
#     'tempo': 107.22,
#     'type': 'audio_features',
#     'id': '1apzxNzMksJZtbDBKFIsdx',
#     'uri': 'spotify:track:1apzxNzMksJZtbDBKFIsdx',
#     'track_href': 'https://api.spotify.com/v1/tracks/1apzxNzMksJZtbDBKFIsdx',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1apzxNzMksJZtbDBKFIsdx',
#     'duration_ms': 254973,
#     'time_signature': 4}]),
#  ('Remember the Time',
#   [{'danceability': 0.831,
#     'energy': 0.921,
#     'key': 5,
#     'loudness': -2.383,
#     'mode': 0,
#     'speechiness': 0.0582,
#     'acousticness': 0.153,
#     'instrumentalness': 0.00224,
#     'liveness': 0.305,
#     'valence': 0.795,
#     'tempo': 108.002,
#     'type': 'audio_features',
#     'id': '4jnFqNWeJCeCRHc4HCdxfd',
#     'uri': 'spotify:track:4jnFqNWeJCeCRHc4HCdxfd',
#     'track_href': 'https://api.spotify.com/v1/tracks/4jnFqNWeJCeCRHc4HCdxfd',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jnFqNWeJCeCRHc4HCdxfd',
#     'duration_ms': 239227,
#     'time_signature': 4}]),
#  ("It's a Shame (My Sister)",
#   [{'danceability': 0.858,
#     'energy': 0.609,
#     'key': 1,
#     'loudness': -10.695,
#     'mode': 1,
#     'speechiness': 0.113,
#     'acousticness': 0.0542,
#     'instrumentalness': 9.04e-05,
#     'liveness': 0.315,
#     'valence': 0.478,
#     'tempo': 107.978,
#     'type': 'audio_features',
#     'id': '2tFAP5PycKceC26ZnIqnBt',
#     'uri': 'spotify:track:2tFAP5PycKceC26ZnIqnBt',
#     'track_href': 'https://api.spotify.com/v1/tracks/2tFAP5PycKceC26ZnIqnBt',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tFAP5PycKceC26ZnIqnBt',
#     'duration_ms': 222840,
#     'time_signature': 4}]),
#  ("Ain't 2 Proud 2 Beg",
#   [{'danceability': 0.674,
#     'energy': 0.707,
#     'key': 10,
#     'loudness': -10.799,
#     'mode': 0,
#     'speechiness': 0.0343,
#     'acousticness': 0.00265,
#     'instrumentalness': 0.00213,
#     'liveness': 0.352,
#     'valence': 0.712,
#     'tempo': 104.855,
#     'type': 'audio_features',
#     'id': '5kVSEpbyuLIVuPM1i2KivC',
#     'uri': 'spotify:track:5kVSEpbyuLIVuPM1i2KivC',
#     'track_href': 'https://api.spotify.com/v1/tracks/5kVSEpbyuLIVuPM1i2KivC',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5kVSEpbyuLIVuPM1i2KivC',
#     'duration_ms': 336560,
#     'time_signature': 4}]),
#  ('You Give Me Something - Blacksmith R&B Remix',
#   [{'danceability': 0.905,
#     'energy': 0.668,
#     'key': 7,
#     'loudness': -5.833,
#     'mode': 1,
#     'speechiness': 0.209,
#     'acousticness': 0.011,
#     'instrumentalness': 0.000777,
#     'liveness': 0.0319,
#     'valence': 0.516,
#     'tempo': 110.026,
#     'type': 'audio_features',
#     'id': '1bQKVFwgiybPuM1bOpBA8w',
#     'uri': 'spotify:track:1bQKVFwgiybPuM1bOpBA8w',
#     'track_href': 'https://api.spotify.com/v1/tracks/1bQKVFwgiybPuM1bOpBA8w',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1bQKVFwgiybPuM1bOpBA8w',
#     'duration_ms': 241160,
#     'time_signature': 4}]),
#  ('Poison',
#   [{'danceability': 0.815,
#     'energy': 0.587,
#     'key': 6,
#     'loudness': -10.161,
#     'mode': 0,
#     'speechiness': 0.237,
#     'acousticness': 0.00179,
#     'instrumentalness': 0.0193,
#     'liveness': 0.645,
#     'valence': 0.754,
#     'tempo': 111.762,
#     'type': 'audio_features',
#     'id': '50DAHcCqneoupFyh96P2GP',
#     'uri': 'spotify:track:50DAHcCqneoupFyh96P2GP',
#     'track_href': 'https://api.spotify.com/v1/tracks/50DAHcCqneoupFyh96P2GP',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50DAHcCqneoupFyh96P2GP',
#     'duration_ms': 261867,
#     'time_signature': 4}]),
#  ('Motownphilly',
#   [{'danceability': 0.754,
#     'energy': 0.857,
#     'key': 2,
#     'loudness': -9.699,
#     'mode': 1,
#     'speechiness': 0.0605,
#     'acousticness': 0.0143,
#     'instrumentalness': 2.14e-05,
#     'liveness': 0.278,
#     'valence': 0.785,
#     'tempo': 114.144,
#     'type': 'audio_features',
#     'id': '4LxIGAVfcQIw0zAQRyFhU8',
#     'uri': 'spotify:track:4LxIGAVfcQIw0zAQRyFhU8',
#     'track_href': 'https://api.spotify.com/v1/tracks/4LxIGAVfcQIw0zAQRyFhU8',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4LxIGAVfcQIw0zAQRyFhU8',
#     'duration_ms': 235227,
#     'time_signature': 4}]),
#  ('Ring Ring Ring',
#   [{'danceability': 0.511,
#     'energy': 0.787,
#     'key': 5,
#     'loudness': -9.11,
#     'mode': 0,
#     'speechiness': 0.371,
#     'acousticness': 0.404,
#     'instrumentalness': 0,
#     'liveness': 0.408,
#     'valence': 0.654,
#     'tempo': 207.966,
#     'type': 'audio_features',
#     'id': '2naf4vnalpvIQaAPZPUNYu',
#     'uri': 'spotify:track:2naf4vnalpvIQaAPZPUNYu',
#     'track_href': 'https://api.spotify.com/v1/tracks/2naf4vnalpvIQaAPZPUNYu',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2naf4vnalpvIQaAPZPUNYu',
#     'duration_ms': 247240,
#     'time_signature': 4}]),
#  ('If I Ruled the World (Imagine That) (feat. Lauryn Hill)',
#   [{'danceability': 0.879,
#     'energy': 0.564,
#     'key': 10,
#     'loudness': -7.682,
#     'mode': 0,
#     'speechiness': 0.247,
#     'acousticness': 0.0474,
#     'instrumentalness': 9.43e-06,
#     'liveness': 0.0519,
#     'valence': 0.523,
#     'tempo': 93.908,
#     'type': 'audio_features',
#     'id': '5PQmSHzWnlgG4EBuIqjac2',
#     'uri': 'spotify:track:5PQmSHzWnlgG4EBuIqjac2',
#     'track_href': 'https://api.spotify.com/v1/tracks/5PQmSHzWnlgG4EBuIqjac2',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5PQmSHzWnlgG4EBuIqjac2',
#     'duration_ms': 282373,
#     'time_signature': 4}]),
#  ('Gin And Juice (feat. Dat Nigga Daz)',
#   [{'danceability': 0.549,
#     'energy': 0.853,
#     'key': 7,
#     'loudness': -4.293,
#     'mode': 1,
#     'speechiness': 0.188,
#     'acousticness': 0.0285,
#     'instrumentalness': 0.000296,
#     'liveness': 0.618,
#     'valence': 0.346,
#     'tempo': 94.695,
#     'type': 'audio_features',
#     'id': '0WKYRFtH6KKbaNWjsxqm70',
#     'uri': 'spotify:track:0WKYRFtH6KKbaNWjsxqm70',
#     'track_href': 'https://api.spotify.com/v1/tracks/0WKYRFtH6KKbaNWjsxqm70',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0WKYRFtH6KKbaNWjsxqm70',
#     'duration_ms': 211493,
#     'time_signature': 4}]),
#  ('Sound of da Police',
#   [{'danceability': 0.794,
#     'energy': 0.95,
#     'key': 1,
#     'loudness': -8.78,
#     'mode': 1,
#     'speechiness': 0.294,
#     'acousticness': 0.124,
#     'instrumentalness': 7.71e-05,
#     'liveness': 0.133,
#     'valence': 0.324,
#     'tempo': 94.984,
#     'type': 'audio_features',
#     'id': '3Y6XWs8xMlCngyIxNOFnsp',
#     'uri': 'spotify:track:3Y6XWs8xMlCngyIxNOFnsp',
#     'track_href': 'https://api.spotify.com/v1/tracks/3Y6XWs8xMlCngyIxNOFnsp',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Y6XWs8xMlCngyIxNOFnsp',
#     'duration_ms': 258507,
#     'time_signature': 4}]),
#  ('Juicy - 2005 Remaster',
#   [{'danceability': 0.889,
#     'energy': 0.818,
#     'key': 9,
#     'loudness': -4.639,
#     'mode': 1,
#     'speechiness': 0.253,
#     'acousticness': 0.47,
#     'instrumentalness': 0,
#     'liveness': 0.179,
#     'valence': 0.782,
#     'tempo': 96.063,
#     'type': 'audio_features',
#     'id': '5ByAIlEEnxYdvpnezg7HTX',
#     'uri': 'spotify:track:5ByAIlEEnxYdvpnezg7HTX',
#     'track_href': 'https://api.spotify.com/v1/tracks/5ByAIlEEnxYdvpnezg7HTX',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ByAIlEEnxYdvpnezg7HTX',
#     'duration_ms': 302760,
#     'time_signature': 4}]),
#  ('I Like It (I Wanna Be Where You Are)',
#   [{'danceability': 0.865,
#     'energy': 0.641,
#     'key': 10,
#     'loudness': -6.652,
#     'mode': 0,
#     'speechiness': 0.162,
#     'acousticness': 0.0611,
#     'instrumentalness': 0.000107,
#     'liveness': 0.218,
#     'valence': 0.762,
#     'tempo': 95.307,
#     'type': 'audio_features',
#     'id': '3nqnWEZnYoetfO2ksMZZVK',
#     'uri': 'spotify:track:3nqnWEZnYoetfO2ksMZZVK',
#     'track_href': 'https://api.spotify.com/v1/tracks/3nqnWEZnYoetfO2ksMZZVK',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3nqnWEZnYoetfO2ksMZZVK',
#     'duration_ms': 263533,
#     'time_signature': 4}]),
#  ('Do For Love',
#   [{'danceability': 0.874,
#     'energy': 0.63,
#     'key': 1,
#     'loudness': -3.585,
#     'mode': 1,
#     'speechiness': 0.298,
#     'acousticness': 0.0578,
#     'instrumentalness': 0.00479,
#     'liveness': 0.0582,
#     'valence': 0.717,
#     'tempo': 95.0,
#     'type': 'audio_features',
#     'id': '4AE7Lj39VnSZNOmGH2iZaq',
#     'uri': 'spotify:track:4AE7Lj39VnSZNOmGH2iZaq',
#     'track_href': 'https://api.spotify.com/v1/tracks/4AE7Lj39VnSZNOmGH2iZaq',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4AE7Lj39VnSZNOmGH2iZaq',
#     'duration_ms': 281600,
#     'time_signature': 4}]),
#  ('Nuthin\' But A "G" Thang',
#   [{'danceability': 0.811,
#     'energy': 0.687,
#     'key': 7,
#     'loudness': -8.685,
#     'mode': 1,
#     'speechiness': 0.282,
#     'acousticness': 0.00685,
#     'instrumentalness': 0,
#     'liveness': 0.0817,
#     'valence': 0.691,
#     'tempo': 94.655,
#     'type': 'audio_features',
#     'id': '5QweA9yLsFBsBtCYJNQ24w',
#     'uri': 'spotify:track:5QweA9yLsFBsBtCYJNQ24w',
#     'track_href': 'https://api.spotify.com/v1/tracks/5QweA9yLsFBsBtCYJNQ24w',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QweA9yLsFBsBtCYJNQ24w',
#     'duration_ms': 238974,
#     'time_signature': 4}]),
#  ("I'll Be There For You/You're All I Need To Get By - Puff Daddy Mix",
#   [{'danceability': 0.722,
#     'energy': 0.745,
#     'key': 4,
#     'loudness': -6.059,
#     'mode': 0,
#     'speechiness': 0.0536,
#     'acousticness': 0.151,
#     'instrumentalness': 6.26e-06,
#     'liveness': 0.337,
#     'valence': 0.607,
#     'tempo': 95.021,
#     'type': 'audio_features',
#     'id': '6C3yPXYG2NJYlIYVe5J7hv',
#     'uri': 'spotify:track:6C3yPXYG2NJYlIYVe5J7hv',
#     'track_href': 'https://api.spotify.com/v1/tracks/6C3yPXYG2NJYlIYVe5J7hv',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6C3yPXYG2NJYlIYVe5J7hv',
#     'duration_ms': 309947,
#     'time_signature': 4}]),
#  ('Electric Relaxation',
#   [{'danceability': 0.866,
#     'energy': 0.534,
#     'key': 11,
#     'loudness': -9.201,
#     'mode': 1,
#     'speechiness': 0.229,
#     'acousticness': 0.184,
#     'instrumentalness': 0.266,
#     'liveness': 0.0929,
#     'valence': 0.841,
#     'tempo': 98.243,
#     'type': 'audio_features',
#     'id': '0eEXcw3JLVXcRxYrVYMy68',
#     'uri': 'spotify:track:0eEXcw3JLVXcRxYrVYMy68',
#     'track_href': 'https://api.spotify.com/v1/tracks/0eEXcw3JLVXcRxYrVYMy68',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0eEXcw3JLVXcRxYrVYMy68',
#     'duration_ms': 226133,
#     'time_signature': 4}]),
#  ('I Wish - Radio Edit',
#   [{'danceability': 0.715,
#     'energy': 0.738,
#     'key': 7,
#     'loudness': -10.139,
#     'mode': 1,
#     'speechiness': 0.157,
#     'acousticness': 0.00826,
#     'instrumentalness': 0,
#     'liveness': 0.26,
#     'valence': 0.573,
#     'tempo': 97.877,
#     'type': 'audio_features',
#     'id': '0QMHVTnrFTQJoaqmkdsKhT',
#     'uri': 'spotify:track:0QMHVTnrFTQJoaqmkdsKhT',
#     'track_href': 'https://api.spotify.com/v1/tracks/0QMHVTnrFTQJoaqmkdsKhT',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0QMHVTnrFTQJoaqmkdsKhT',
#     'duration_ms': 252307,
#     'time_signature': 4}]),
#  ('Full Clip',
#   [{'danceability': 0.875,
#     'energy': 0.745,
#     'key': 1,
#     'loudness': -5.878,
#     'mode': 1,
#     'speechiness': 0.269,
#     'acousticness': 0.0227,
#     'instrumentalness': 2.37e-06,
#     'liveness': 0.287,
#     'valence': 0.749,
#     'tempo': 95.201,
#     'type': 'audio_features',
#     'id': '30oTS7bm0aH3p7lqjEIu8q',
#     'uri': 'spotify:track:30oTS7bm0aH3p7lqjEIu8q',
#     'track_href': 'https://api.spotify.com/v1/tracks/30oTS7bm0aH3p7lqjEIu8q',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/30oTS7bm0aH3p7lqjEIu8q',
#     'duration_ms': 217440,
#     'time_signature': 4}]),
#  ('Ms. Fat Booty',
#   [{'danceability': 0.782,
#     'energy': 0.589,
#     'key': 1,
#     'loudness': -4.827,
#     'mode': 1,
#     'speechiness': 0.189,
#     'acousticness': 0.148,
#     'instrumentalness': 0,
#     'liveness': 0.164,
#     'valence': 0.869,
#     'tempo': 90.438,
#     'type': 'audio_features',
#     'id': '0IVAlb0cFCH1cQ974iR1TU',
#     'uri': 'spotify:track:0IVAlb0cFCH1cQ974iR1TU',
#     'track_href': 'https://api.spotify.com/v1/tracks/0IVAlb0cFCH1cQ974iR1TU',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0IVAlb0cFCH1cQ974iR1TU',
#     'duration_ms': 223547,
#     'time_signature': 4}]),
#  ("Heart Of The City (Ain't No Love)",
#   [{'danceability': 0.606,
#     'energy': 0.943,
#     'key': 6,
#     'loudness': -3.948,
#     'mode': 1,
#     'speechiness': 0.276,
#     'acousticness': 0.088,
#     'instrumentalness': 0.0039,
#     'liveness': 0.342,
#     'valence': 0.802,
#     'tempo': 171.027,
#     'type': 'audio_features',
#     'id': '6gpZSI0xEMTzleBc5ykOVA',
#     'uri': 'spotify:track:6gpZSI0xEMTzleBc5ykOVA',
#     'track_href': 'https://api.spotify.com/v1/tracks/6gpZSI0xEMTzleBc5ykOVA',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6gpZSI0xEMTzleBc5ykOVA',
#     'duration_ms': 223240,
#     'time_signature': 4}]),
#  ('Ten Crack Commandments - 2014 Remaster',
#   [{'danceability': 0.612,
#     'energy': 0.85,
#     'key': 1,
#     'loudness': -4.703,
#     'mode': 1,
#     'speechiness': 0.5,
#     'acousticness': 0.0393,
#     'instrumentalness': 0,
#     'liveness': 0.255,
#     'valence': 0.781,
#     'tempo': 173.497,
#     'type': 'audio_features',
#     'id': '1Z7C8ClE8UEaH70jCCeJH2',
#     'uri': 'spotify:track:1Z7C8ClE8UEaH70jCCeJH2',
#     'track_href': 'https://api.spotify.com/v1/tracks/1Z7C8ClE8UEaH70jCCeJH2',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Z7C8ClE8UEaH70jCCeJH2',
#     'duration_ms': 204027,
#     'time_signature': 4}]),
#  ('Flava in Ya Ear - Club Mix',
#   [{'danceability': 0.779,
#     'energy': 0.483,
#     'key': 9,
#     'loudness': -11.098,
#     'mode': 0,
#     'speechiness': 0.332,
#     'acousticness': 0.544,
#     'instrumentalness': 0,
#     'liveness': 0.0562,
#     'valence': 0.865,
#     'tempo': 90.073,
#     'type': 'audio_features',
#     'id': '7fcTciTYcKnwrSnbzD5MkR',
#     'uri': 'spotify:track:7fcTciTYcKnwrSnbzD5MkR',
#     'track_href': 'https://api.spotify.com/v1/tracks/7fcTciTYcKnwrSnbzD5MkR',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7fcTciTYcKnwrSnbzD5MkR',
#     'duration_ms': 222773,
#     'time_signature': 4}]),
#  ('C.R.E.A.M. (Cash Rules Everything Around Me) (feat. Method Man, Raekwon, Inspectah Deck & Buddha Monk)',
#   [{'danceability': 0.479,
#     'energy': 0.549,
#     'key': 11,
#     'loudness': -10.551,
#     'mode': 0,
#     'speechiness': 0.373,
#     'acousticness': 0.57,
#     'instrumentalness': 0.0235,
#     'liveness': 0.127,
#     'valence': 0.576,
#     'tempo': 180.985,
#     'type': 'audio_features',
#     'id': '119c93MHjrDLJTApCVGpvx',
#     'uri': 'spotify:track:119c93MHjrDLJTApCVGpvx',
#     'track_href': 'https://api.spotify.com/v1/tracks/119c93MHjrDLJTApCVGpvx',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/119c93MHjrDLJTApCVGpvx',
#     'duration_ms': 252187,
#     'time_signature': 4}]),
#  ('Oooh',
#   [{'danceability': 0.796,
#     'energy': 0.621,
#     'key': 0,
#     'loudness': -7.954,
#     'mode': 1,
#     'speechiness': 0.346,
#     'acousticness': 0.189,
#     'instrumentalness': 0,
#     'liveness': 0.322,
#     'valence': 0.834,
#     'tempo': 92.232,
#     'type': 'audio_features',
#     'id': '5BTyidbhMPbTNGV7jTH9Dx',
#     'uri': 'spotify:track:5BTyidbhMPbTNGV7jTH9Dx',
#     'track_href': 'https://api.spotify.com/v1/tracks/5BTyidbhMPbTNGV7jTH9Dx',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5BTyidbhMPbTNGV7jTH9Dx',
#     'duration_ms': 214600,
#     'time_signature': 4}]),
#  ('Work',
#   [{'danceability': 0.787,
#     'energy': 0.832,
#     'key': 10,
#     'loudness': -4.671,
#     'mode': 1,
#     'speechiness': 0.301,
#     'acousticness': 0.0347,
#     'instrumentalness': 0,
#     'liveness': 0.0593,
#     'valence': 0.814,
#     'tempo': 92.606,
#     'type': 'audio_features',
#     'id': '1EiLrPd8JMTcQUr1aLEUKi',
#     'uri': 'spotify:track:1EiLrPd8JMTcQUr1aLEUKi',
#     'track_href': 'https://api.spotify.com/v1/tracks/1EiLrPd8JMTcQUr1aLEUKi',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1EiLrPd8JMTcQUr1aLEUKi',
#     'duration_ms': 177667,
#     'time_signature': 4}]),
#  ('Jamboree (feat. Zhané)',
#   [{'danceability': 0.849,
#     'energy': 0.635,
#     'key': 0,
#     'loudness': -9.425,
#     'mode': 1,
#     'speechiness': 0.266,
#     'acousticness': 0.0344,
#     'instrumentalness': 0,
#     'liveness': 0.082,
#     'valence': 0.856,
#     'tempo': 92.003,
#     'type': 'audio_features',
#     'id': '3MPKTMJIxlORqcxw542HHK',
#     'uri': 'spotify:track:3MPKTMJIxlORqcxw542HHK',
#     'track_href': 'https://api.spotify.com/v1/tracks/3MPKTMJIxlORqcxw542HHK',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3MPKTMJIxlORqcxw542HHK',
#     'duration_ms': 213907,
#     'time_signature': 4}]),
#  ('Shook Ones, Pt. II',
#   [{'danceability': 0.763,
#     'energy': 0.786,
#     'key': 10,
#     'loudness': -6.472,
#     'mode': 0,
#     'speechiness': 0.229,
#     'acousticness': 0.0146,
#     'instrumentalness': 0.0114,
#     'liveness': 0.0817,
#     'valence': 0.504,
#     'tempo': 93.857,
#     'type': 'audio_features',
#     'id': '33ZXjLCpiINn8eQIDYEPTD',
#     'uri': 'spotify:track:33ZXjLCpiINn8eQIDYEPTD',
#     'track_href': 'https://api.spotify.com/v1/tracks/33ZXjLCpiINn8eQIDYEPTD',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33ZXjLCpiINn8eQIDYEPTD',
#     'duration_ms': 325507,
#     'time_signature': 4}]),
#  ('Insane in the Brain',
#   [{'danceability': 0.902,
#     'energy': 0.705,
#     'key': 8,
#     'loudness': -7.253,
#     'mode': 0,
#     'speechiness': 0.22,
#     'acousticness': 0.0233,
#     'instrumentalness': 0.193,
#     'liveness': 0.118,
#     'valence': 0.77,
#     'tempo': 102.221,
#     'type': 'audio_features',
#     'id': '4dTMU4O2DdyIlRlss7v9UP',
#     'uri': 'spotify:track:4dTMU4O2DdyIlRlss7v9UP',
#     'track_href': 'https://api.spotify.com/v1/tracks/4dTMU4O2DdyIlRlss7v9UP',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4dTMU4O2DdyIlRlss7v9UP',
#     'duration_ms': 206893,
#     'time_signature': 4}]),
#  ("Ain't No Fun (If the Homies Cant Have None) (feat. Nate Dogg, Warren G & Kurupt)",
#   [{'danceability': 0.84,
#     'energy': 0.798,
#     'key': 8,
#     'loudness': -5.079,
#     'mode': 1,
#     'speechiness': 0.0699,
#     'acousticness': 0.045,
#     'instrumentalness': 4.32e-05,
#     'liveness': 0.172,
#     'valence': 0.695,
#     'tempo': 100.175,
#     'type': 'audio_features',
#     'id': '4rLpAOk5KVNcqEMK3m6Lje',
#     'uri': 'spotify:track:4rLpAOk5KVNcqEMK3m6Lje',
#     'track_href': 'https://api.spotify.com/v1/tracks/4rLpAOk5KVNcqEMK3m6Lje',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4rLpAOk5KVNcqEMK3m6Lje',
#     'duration_ms': 246347,
#     'time_signature': 4}]),
#  ('Saturdays',
#   [{'danceability': 0.913,
#     'energy': 0.815,
#     'key': 1,
#     'loudness': -7.867,
#     'mode': 1,
#     'speechiness': 0.13,
#     'acousticness': 0.0059,
#     'instrumentalness': 0.000996,
#     'liveness': 0.064,
#     'valence': 0.821,
#     'tempo': 114.958,
#     'type': 'audio_features',
#     'id': '53NJIzVHhPQnMKdsjsnfiQ',
#     'uri': 'spotify:track:53NJIzVHhPQnMKdsjsnfiQ',
#     'track_href': 'https://api.spotify.com/v1/tracks/53NJIzVHhPQnMKdsjsnfiQ',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/53NJIzVHhPQnMKdsjsnfiQ',
#     'duration_ms': 197000,
#     'time_signature': 4}]),
#  ('Me Myself And I',
#   [{'danceability': 0.898,
#     'energy': 0.92,
#     'key': 5,
#     'loudness': -7.859,
#     'mode': 1,
#     'speechiness': 0.0636,
#     'acousticness': 0.0711,
#     'instrumentalness': 5.92e-05,
#     'liveness': 0.0908,
#     'valence': 0.875,
#     'tempo': 114.343,
#     'type': 'audio_features',
#     'id': '1o7pq0fvaVfQSKOKwQAHSo',
#     'uri': 'spotify:track:1o7pq0fvaVfQSKOKwQAHSo',
#     'track_href': 'https://api.spotify.com/v1/tracks/1o7pq0fvaVfQSKOKwQAHSo',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1o7pq0fvaVfQSKOKwQAHSo',
#     'duration_ms': 224693,
#     'time_signature': 4}]),
#  ('It Takes Two',
#   [{'danceability': 0.8,
#     'energy': 0.723,
#     'key': 2,
#     'loudness': -9.719,
#     'mode': 1,
#     'speechiness': 0.158,
#     'acousticness': 0.00228,
#     'instrumentalness': 0,
#     'liveness': 0.26,
#     'valence': 0.651,
#     'tempo': 111.593,
#     'type': 'audio_features',
#     'id': '0gFB5H3pHN13ERt2FyMuWi',
#     'uri': 'spotify:track:0gFB5H3pHN13ERt2FyMuWi',
#     'track_href': 'https://api.spotify.com/v1/tracks/0gFB5H3pHN13ERt2FyMuWi',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0gFB5H3pHN13ERt2FyMuWi',
#     'duration_ms': 300640,
#     'time_signature': 4}]),
#  ('The Breaks',
#   [{'danceability': 0.818,
#     'energy': 0.67,
#     'key': 11,
#     'loudness': -13.912,
#     'mode': 0,
#     'speechiness': 0.0757,
#     'acousticness': 0.122,
#     'instrumentalness': 0.00156,
#     'liveness': 0.31,
#     'valence': 0.917,
#     'tempo': 112.704,
#     'type': 'audio_features',
#     'id': '19tYXOfQFZ7gdGA3LAH76I',
#     'uri': 'spotify:track:19tYXOfQFZ7gdGA3LAH76I',
#     'track_href': 'https://api.spotify.com/v1/tracks/19tYXOfQFZ7gdGA3LAH76I',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/19tYXOfQFZ7gdGA3LAH76I',
#     'duration_ms': 469267,
#     'time_signature': 4}]),
#  ("Rapper's Delight - Single Version",
#   [{'danceability': 0.917,
#     'energy': 0.692,
#     'key': 2,
#     'loudness': -11.665,
#     'mode': 1,
#     'speechiness': 0.244,
#     'acousticness': 0.185,
#     'instrumentalness': 1.09e-05,
#     'liveness': 0.0686,
#     'valence': 0.819,
#     'tempo': 111.782,
#     'type': 'audio_features',
#     'id': '0tm6gsXe0LSm9zeSspyMQu',
#     'uri': 'spotify:track:0tm6gsXe0LSm9zeSspyMQu',
#     'track_href': 'https://api.spotify.com/v1/tracks/0tm6gsXe0LSm9zeSspyMQu',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tm6gsXe0LSm9zeSspyMQu',
#     'duration_ms': 235840,
#     'time_signature': 4}]),
#  ('Mentirosa',
#   [{'danceability': 0.966,
#     'energy': 0.505,
#     'key': 1,
#     'loudness': -14.762,
#     'mode': 1,
#     'speechiness': 0.111,
#     'acousticness': 0.0678,
#     'instrumentalness': 0,
#     'liveness': 0.197,
#     'valence': 0.826,
#     'tempo': 113.592,
#     'type': 'audio_features',
#     'id': '3P6fS71hWhZvOnnxQojJ0Z',
#     'uri': 'spotify:track:3P6fS71hWhZvOnnxQojJ0Z',
#     'track_href': 'https://api.spotify.com/v1/tracks/3P6fS71hWhZvOnnxQojJ0Z',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3P6fS71hWhZvOnnxQojJ0Z',
#     'duration_ms': 258533,
#     'time_signature': 4}]),
#  ('Ice Ice Baby',
#   [{'danceability': 0.979,
#     'energy': 0.792,
#     'key': 2,
#     'loudness': -2.784,
#     'mode': 1,
#     'speechiness': 0.0388,
#     'acousticness': 0.0025,
#     'instrumentalness': 7.71e-06,
#     'liveness': 0.102,
#     'valence': 0.583,
#     'tempo': 116.012,
#     'type': 'audio_features',
#     'id': '3XVozq1aeqsJwpXrEZrDJ9',
#     'uri': 'spotify:track:3XVozq1aeqsJwpXrEZrDJ9',
#     'track_href': 'https://api.spotify.com/v1/tracks/3XVozq1aeqsJwpXrEZrDJ9',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3XVozq1aeqsJwpXrEZrDJ9',
#     'duration_ms': 254467,
#     'time_signature': 4}]),
#  ('Now That We Found Love',
#   [{'danceability': 0.744,
#     'energy': 0.697,
#     'key': 8,
#     'loudness': -14.753,
#     'mode': 1,
#     'speechiness': 0.0631,
#     'acousticness': 0.039,
#     'instrumentalness': 0,
#     'liveness': 0.171,
#     'valence': 0.683,
#     'tempo': 119.955,
#     'type': 'audio_features',
#     'id': '1KONmY3enP3r3nIPQidWAy',
#     'uri': 'spotify:track:1KONmY3enP3r3nIPQidWAy',
#     'track_href': 'https://api.spotify.com/v1/tracks/1KONmY3enP3r3nIPQidWAy',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1KONmY3enP3r3nIPQidWAy',
#     'duration_ms': 258200,
#     'time_signature': 4}]),
#  ('Bust A Move',
#   [{'danceability': 0.954,
#     'energy': 0.614,
#     'key': 4,
#     'loudness': -11.48,
#     'mode': 1,
#     'speechiness': 0.106,
#     'acousticness': 0.0816,
#     'instrumentalness': 9.25e-05,
#     'liveness': 0.086,
#     'valence': 0.839,
#     'tempo': 117.548,
#     'type': 'audio_features',
#     'id': '4CYyheknaH5R2xfEndtixD',
#     'uri': 'spotify:track:4CYyheknaH5R2xfEndtixD',
#     'track_href': 'https://api.spotify.com/v1/tracks/4CYyheknaH5R2xfEndtixD',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4CYyheknaH5R2xfEndtixD',
#     'duration_ms': 265667,
#     'time_signature': 4}]),
#  ('Apache (Jump On It)',
#   [{'danceability': 0.824,
#     'energy': 0.886,
#     'key': 7,
#     'loudness': -9.929,
#     'mode': 1,
#     'speechiness': 0.139,
#     'acousticness': 0.274,
#     'instrumentalness': 0,
#     'liveness': 0.0694,
#     'valence': 0.25,
#     'tempo': 115.02,
#     'type': 'audio_features',
#     'id': '5mMxriCaSYyZopQDPYkyqT',
#     'uri': 'spotify:track:5mMxriCaSYyZopQDPYkyqT',
#     'track_href': 'https://api.spotify.com/v1/tracks/5mMxriCaSYyZopQDPYkyqT',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mMxriCaSYyZopQDPYkyqT',
#     'duration_ms': 374760,
#     'time_signature': 4}]),
#  ('Thong Song',
#   [{'danceability': 0.706,
#     'energy': 0.888,
#     'key': 2,
#     'loudness': -6.959,
#     'mode': 1,
#     'speechiness': 0.0654,
#     'acousticness': 0.119,
#     'instrumentalness': 9.64e-05,
#     'liveness': 0.07,
#     'valence': 0.714,
#     'tempo': 121.549,
#     'type': 'audio_features',
#     'id': '5Mmk2ii6laakqfeCT7OnVD',
#     'uri': 'spotify:track:5Mmk2ii6laakqfeCT7OnVD',
#     'track_href': 'https://api.spotify.com/v1/tracks/5Mmk2ii6laakqfeCT7OnVD',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Mmk2ii6laakqfeCT7OnVD',
#     'duration_ms': 253733,
#     'time_signature': 4}]),
#  ('Promised Land',
#   [{'danceability': 0.718,
#     'energy': 0.93,
#     'key': 7,
#     'loudness': -4.532,
#     'mode': 1,
#     'speechiness': 0.038,
#     'acousticness': 0.0026,
#     'instrumentalness': 0.0176,
#     'liveness': 0.0363,
#     'valence': 0.697,
#     'tempo': 128.736,
#     'type': 'audio_features',
#     'id': '796T2ROxTNibXRjVhjSzCa',
#     'uri': 'spotify:track:796T2ROxTNibXRjVhjSzCa',
#     'track_href': 'https://api.spotify.com/v1/tracks/796T2ROxTNibXRjVhjSzCa',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/796T2ROxTNibXRjVhjSzCa',
#     'duration_ms': 331706,
#     'time_signature': 4}]),
#  ('Lucky Star',
#   [{'danceability': 0.776,
#     'energy': 0.682,
#     'key': 6,
#     'loudness': -7.426,
#     'mode': 1,
#     'speechiness': 0.0738,
#     'acousticness': 0.0516,
#     'instrumentalness': 0.000237,
#     'liveness': 0.234,
#     'valence': 0.901,
#     'tempo': 125.857,
#     'type': 'audio_features',
#     'id': '5EMwg8P4A3Qj7BPtau1Mn0',
#     'uri': 'spotify:track:5EMwg8P4A3Qj7BPtau1Mn0',
#     'track_href': 'https://api.spotify.com/v1/tracks/5EMwg8P4A3Qj7BPtau1Mn0',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5EMwg8P4A3Qj7BPtau1Mn0',
#     'duration_ms': 295693,
#     'time_signature': 4}]),
#  ('I Wanna Be Your Lover',
#   [{'danceability': 0.812,
#     'energy': 0.507,
#     'key': 1,
#     'loudness': -8.825,
#     'mode': 0,
#     'speechiness': 0.0452,
#     'acousticness': 0.0399,
#     'instrumentalness': 0.0831,
#     'liveness': 0.0671,
#     'valence': 0.729,
#     'tempo': 114.832,
#     'type': 'audio_features',
#     'id': '4yrM5BVyJzy5Ed4GPO6e8j',
#     'uri': 'spotify:track:4yrM5BVyJzy5Ed4GPO6e8j',
#     'track_href': 'https://api.spotify.com/v1/tracks/4yrM5BVyJzy5Ed4GPO6e8j',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4yrM5BVyJzy5Ed4GPO6e8j',
#     'duration_ms': 347667,
#     'time_signature': 4}])]

# %%
pd.DataFrame.from_dict(get_tracks)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-8ae7faaf2c14> in <module>
# ----> 1 pd.DataFrame.from_dict(get_tracks)
#
# ~/opt/anaconda3/envs/andyclass/lib/python3.6/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1307             raise ValueError("only recognize index or columns for orient")
#    1308
# -> 1309         return cls(data, index=index, columns=columns, dtype=dtype)
#    1310
#    1311     def to_numpy(
#
# ~/opt/anaconda3/envs/andyclass/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527         else:
#     528             if index is None or columns is None:
# --> 529                 raise ValueError("DataFrame constructor not properly called!")
#     530
#     531             if not dtype:
#
# ValueError: DataFrame constructor not properly called!

# %% [markdown]
# Function to extract all songs from a playlist

# %% [markdown]
# Function to extract just the uri's:

# %% [markdown]
# #### Pagination using "next"
#
# When you collect songs from a playlist using `sp.playlist_tracks`, you're limited by the `limit` parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter `offset` allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function `sp.next()` does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key `next` on the results from any request.

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %% [markdown]
# Above, we stored all the uri's of a playlist into a list called `iron_uris`. We're going to get all the audio features from that playlist's songs now.

# %% [markdown]
# ### Searching the audio features for a song
#
# When the user inputs a song, you are gonna want to retrieve the audio features of that song. How to do it?
#
# 1. Search the user input using the `sp.search()` function. This function works similarly to the "search" bar on the spotify app - using Spotify's intelligent search engine. That means that it can handle names of any songs or artists - even certain typos.
#
# 2. Find the uri of the song that the API gives you back.
#
# 3. Use `sp.audio_features` to retrieve the audio features of the song.

# %% [markdown]
# ### Lab: Create your collection of songs & audio features
#
# To move forward witht the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster.
#
# The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!
