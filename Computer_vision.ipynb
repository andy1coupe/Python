# %% [markdown]
# https://sandrarose.com/2022/01/amazons-gender-recognition-software-identifies-michelle-obama-and-serena-williams-as-men/
#
# Recently there was news about Amazon's gender recognition software which seemingly shows gender and racial bias, and recent studies have confirmed that bias. Studies led by Buolamwini found huge racial and gender bias in the facial recognition software.
#
# The use of this type of software could possibly create racial or gender problems as the system is seemingly biased or trained with incorrect data.  In this instance and due to protests of its use, Amazon made the decision to suspend police use of its software.

# %%
#this image was generated with https://vision-explorer.allenai.org/text_to_image_generation
# generated using dropdown"clock tower" and text "save the clock tower, it was struck by lightening in 1955"

# %matplotlib inline
from IPython.display import Image
Image('download.png')

# %% [markdown]
# https://thedatafrog.com/en/articles/dogs-vs-cats/
#
#
# image processing steps used:
#
# - images were imported as a dataset
# - checked the dataset looking at first two images in each category
# - clean up data
# - plot images with labels
# - split the data into training and validation
# - set up simple convolutional neuro network
# - checking for underfitting and overfitting
# - train dataset
# - check results
# - data augmentation - re-training with results to get better accuracy
# - using a pretrained model resnet50/keras
# - conclusion and outlook
